# %% [markdown]
# # Assignment 2

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error
import os
from torch.optim import SGD, Adam
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau

print('seaborn:', sns.__version__)
print('pandas:', pd.__version__)
print('numpy:', np.__version__)
print('torch:', torch.__version__)

# Define a function to set the seed
def set_seed(seed):
    """
    Sets the seed for reproducibility using numpy and torch.
    """
    # Set seed for numpy
    np.random.seed(seed)
    print(f"Numpy random seed set to: {seed}")
    
    # Set seed for torch (CPU and GPU)
    torch.manual_seed(seed)  # For CPU
    torch.use_deterministic_algorithms(mode=True)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)  # For current GPU
        torch.cuda.manual_seed_all(seed)  # For all GPUs
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f"Torch random seed set to: {seed}")

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    torch.manual_seed(worker_seed) 

generator = torch.Generator()
generator.manual_seed(0)

# Use the function
seed = 42
set_seed(seed)
# Out:
# seaborn: 0.13.2
# pandas: 2.2.3
# numpy: 2.1.2
# torch: 2.4.1+cpu
# Numpy random seed set to: 42
# Torch random seed set to: 42

# %% [markdown]
# ## Task a)

# %%
set_seed(seed)
# Splitting the data into train and test set
X, y = fetch_california_housing(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=302)

columns=["MedInc", "HouseAge", "AveRooms", "AveBedrms", "Population", "AveOccup", "Lat", "Long", "MedHouseVal"]
data = pd.DataFrame(data=np.column_stack((X_train, y_train)), columns=columns)

print("Size of the data:")
print(data.shape)

data.head()
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
# Size of the data:
# (15480, 9)
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup    Lat    Long  \
# 0  3.3409      32.0  3.254902   1.009804       177.0  1.735294  33.90 -118.37
# 1  4.0000      35.0  4.938095   0.985714       552.0  2.628571  37.71 -122.12
# 2  4.1997      17.0  5.732759   1.060345      2866.0  3.088362  38.66 -121.76
# 3  5.6163      27.0  6.515670   1.005698      1140.0  3.247863  33.83 -117.87
# 4  1.6559      48.0  5.161663   1.000000      1363.0  3.147806  33.99 -118.31
#
#    MedHouseVal
# 0        2.563
# 1        1.679
# 2        1.334
# 3        2.310
# 4        1.014

# %%
print("Structure of the data:")
print(data.describe())
# Out:
# Structure of the data:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  15480.000000  15480.000000  15480.000000  15480.000000  15480.000000
# mean       3.867932     28.634044      5.431607      1.095960   1421.528811
# std        1.899344     12.642321      2.388734      0.427406   1124.197972
# min        0.499900      1.000000      0.846154      0.375000      3.000000
# 25%        2.565800     18.000000      4.443769      1.006118    787.000000
# 50%        3.528800     29.000000      5.230702      1.048833   1163.000000
# 75%        4.744150     37.000000      6.060497      1.099431   1719.250000
# max       15.000100     52.000000    141.909091     25.636364  35682.000000
#
#            AveOccup           Lat          Long   MedHouseVal
# count  15480.000000  15480.000000  15480.000000  15480.000000
# mean       3.112156     35.634422   -119.569263      2.068206
# std       11.959223      2.138867      2.004747      1.156928
# min        0.692308     32.560000   -124.350000      0.149990
# 25%        2.431797     33.930000   -121.790000      1.189000
# 50%        2.823972     34.250000   -118.490000      1.798000
# 75%        3.282093     37.720000   -118.000000      2.647000
# max     1243.333333     41.950000   -114.470000      5.000010

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       15480 non-null  float64
#  1   HouseAge     15480 non-null  float64
#  2   AveRooms     15480 non-null  float64
#  3   AveBedrms    15480 non-null  float64
#  4   Population   15480 non-null  float64
#  5   AveOccup     15480 non-null  float64
#  6   Lat          15480 non-null  float64
#  7   Long         15480 non-null  float64
#  8   MedHouseVal  15480 non-null  float64
# dtypes: float64(9)
# memory usage: 1.1 MB
# None

# %%
# Plotting feature distributions
def plot_feature_distributions(data, title):
    plt.figure(figsize=(15, 10))
    for i, column in enumerate(data.columns, 1):
        plt.subplot(3, 3, i)
        sns.histplot(data[column], kde=True, bins=30)
        plt.title(column)
    plt.tight_layout()
    plt.suptitle(title, y=1.02, fontsize=16)
    plt.show()

plot_feature_distributions(data.iloc[:, :-1], "Feature Distributions in Dataset")

# %%
# Scatter plot to observe relationships between features and the target variable.
scatter_matrix = pd.plotting.scatter_matrix(
    data,
    alpha=0.25,
    figsize=(16, 16),
    diagonal="kde",
    marker="o"
)
plt.suptitle("Feature Relationships and Distributions", fontsize=18, y=1.02)
plt.show()

# %%
features = ["MedInc", "HouseAge", "AveRooms", "AveBedrms", "Population", "AveOccup", "Lat", "Long"]
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(30, 20))

for index, (axis, feature) in enumerate(zip(axes.flat, features)):
    feature_data = X[:, index] 
    fit_params = np.polyfit(feature_data, y, 1)
    linear_model = np.poly1d(fit_params)

    axis.scatter(feature_data, y, color='blue', label='Data points')
    axis.plot(feature_data, linear_model(feature_data), 'r--', label='Fitted line')

    axis.set_title(f"{feature} vs Median House Value")
    axis.set_xlabel(feature)
    axis.set_ylabel('Median House Value')
    axis.legend()

plt.tight_layout()
plt.show()

# %%
# Missing values count
print("Number of missing values")
print("------------------------------")
missing_values = data.isnull().sum()
missing_percentage = (missing_values / len(data)) * 100
missing_info = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
})
print(missing_info)

print("\nNumber of unique values")
print("------------------------------")
unique_values = data.nunique()
print(unique_values)
# Out:
# Number of missing values
# ------------------------------
#              Missing Values  Percentage
# MedInc                    0         0.0
# HouseAge                  0         0.0
# AveRooms                  0         0.0
# AveBedrms                 0         0.0
# Population                0         0.0
# AveOccup                  0         0.0
# Lat                       0         0.0
# Long                      0         0.0
# MedHouseVal               0         0.0
#
# Number of unique values
# ------------------------------
# MedInc         10372
# HouseAge          52
# AveRooms       14722
# AveBedrms      11369
# Population      3563
# AveOccup       14356
# Lat              840
# Long             811
# MedHouseVal     3602
# dtype: int64

# %%
print("Correlation matrix for features")
print("------------------------------")
correlation_matrix = data.corr()
print(correlation_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation matrix for features
# ------------------------------
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.126398  0.338891  -0.070325    0.006030  0.022880
# HouseAge    -0.126398  1.000000 -0.164742  -0.089941   -0.296191  0.015903
# AveRooms     0.338891 -0.164742  1.000000   0.836048   -0.076527 -0.004385
# AveBedrms   -0.070325 -0.089941  0.836048   1.000000   -0.071595 -0.005768
# Population   0.006030 -0.296191 -0.076527  -0.071595    1.000000  0.074505
# AveOccup     0.022880  0.015903 -0.004385  -0.005768    0.074505  1.000000
# Lat         -0.077792  0.010531  0.113740   0.077687   -0.105442  0.006585
# Long        -0.017599 -0.109259 -0.033491   0.012110    0.098350 -0.001187
# MedHouseVal  0.689480  0.101697  0.163119  -0.049184   -0.023517 -0.021679
#
#                   Lat      Long  MedHouseVal
# MedInc      -0.077792 -0.017599     0.689480
# HouseAge     0.010531 -0.109259     0.101697
# AveRooms     0.113740 -0.033491     0.163119
# AveBedrms    0.077687  0.012110    -0.049184
# Population  -0.105442  0.098350    -0.023517
# AveOccup     0.006585 -0.001187    -0.021679
# Lat          1.000000 -0.924282    -0.145960
# Long        -0.924282  1.000000    -0.045007
# MedHouseVal -0.145960 -0.045007     1.000000

# %%
print("Number of outliers:")
print("------------------------------")
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

# Define outliers as values outside 1.5*IQR
outliers = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))

outliers_count = outliers.sum()
print(outliers_count)
# Out:
# Number of outliers:
# ------------------------------
# MedInc          513
# HouseAge          0
# AveRooms        384
# AveBedrms      1060
# Population      908
# AveOccup        532
# Lat               0
# Long              0
# MedHouseVal     793
# dtype: int64

# %%
set_seed(seed)
# Preprocessing
# Normalization
scaler = StandardScaler()
x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

# Split X_train to validation and train data
X_new_train, X_val, y_new_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=302)
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42

# %% [markdown]
# ## Task b)

# %%
set_seed(seed)
# Convert to PyTorch tensors
X_new_train = torch.tensor(X_new_train).float()
y_new_train = torch.tensor(y_new_train).view(-1, 1).float()

X_val = torch.tensor(X_val).float()
y_val = torch.tensor(y_val).view(-1, 1).float()

X_test = torch.tensor(x_test).float()
y_test = torch.tensor(y_test).view(-1, 1).float()
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42

# %%
set_seed(seed)
generator = torch.Generator()
generator.manual_seed(0)

def train_with_batch_size(model_fn, batch_size, num_epochs=200, patience=10):
    # Adjust learning rate based on batch size
    base_lr = 0.0001
    adjusted_lr = base_lr * (batch_size ** 0.5)

    train_dataset = TensorDataset(X_new_train, y_new_train)
    train_iter = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,worker_init_fn=seed_worker,generator=generator)

    val_dataset = TensorDataset(X_val, y_val)
    val_iter = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,worker_init_fn=seed_worker,generator=generator)

    model = model_fn()
    criterion = nn.MSELoss()
    optimizer = torch.optim.RMSprop(model.parameters(), lr=adjusted_lr)
    
    train_losses = []
    val_losses = []
    
    # Early stopping variables
    best_val_loss = float('inf')
    best_train_loss = None 
    epochs_no_improve = 0
    early_stop = False
    
    for epoch in range(num_epochs):
        if early_stop:
            print(f"Early stopping at epoch {epoch}")
            break

        running_train_loss = 0.0
        model.train()
        
        # Training loop
        for inputs, labels in train_iter:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item()
        
        # Validation loop
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_iter:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
        
        # Calculate averate train and validation losses
        avg_train_loss = running_train_loss / len(train_iter)
        avg_val_loss = running_val_loss / len(val_iter)
        
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Check for early stopping
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_train_loss = avg_train_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        if epochs_no_improve >= patience:
            early_stop = True
    
    # Evaluate the model on test data
    model.eval()
    with torch.no_grad():
        test_outputs = model(X_test)
        test_rmse = np.sqrt(mean_squared_error(test_outputs.numpy(), y_test.numpy()))

    return best_val_loss, test_rmse, best_train_loss

set_seed(seed)
# We will use a fixed model to see if its loss changes with different batch sizes

def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.normal_(m.weight, mean=0, std=0.01)  # Manual initialization of weights
        m.bias.data.fill_(0.0001)  # Bias initialization

def create_model():
    model = nn.Sequential(
        nn.Linear(8, 100),
        nn.ReLU(),
        nn.Linear(100, 50),
        nn.ReLU(),
        nn.Linear(50, 10),
        nn.ReLU(),
        nn.Linear(10, 1)
    )
    
    # Apply custom weight initialization
    model.apply(init_weights)
    
    return model

# Batch sizes to test
batch_sizes = [16, 32, 50, 64, 128, 256]
results = []

# Running experiments on every batch size
for batch_size in batch_sizes:
    print(f"Testing batch size: {batch_size}")
    val_loss, test_rmse, train_loss = train_with_batch_size(create_model, batch_size)
    results.append({'Batch Size': batch_size,'Train Loss': train_loss, 'Validation Loss': val_loss, 'Test RMSE': test_rmse })
    print(f"Batch Size: {batch_size}, Train Loss: {train_loss:.3f}, Validation Loss: {val_loss:.3f}, Test RMSE: {test_rmse:.3f}")

results_df = pd.DataFrame(results)
print(results_df)

best_result = results_df.loc[results_df['Validation Loss'].idxmin()]
print(f"Best Batch Size: {best_result['Batch Size']} with "
      f"Validation Loss: {best_result['Validation Loss']:.3f}, "
      f"Test RMSE: {best_result['Test RMSE']:.3f}, "
      f"Train Loss: {best_result['Train Loss']:.3f}")
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
# Numpy random seed set to: 42
# Torch random seed set to: 42
# Testing batch size: 16
# Early stopping at epoch 107
# Batch Size: 16, Train Loss: 0.263, Validation Loss: 0.294, Test RMSE: 0.535
# Testing batch size: 32
# Early stopping at epoch 96
# Batch Size: 32, Train Loss: 0.277, Validation Loss: 0.303, Test RMSE: 0.535
# Testing batch size: 50
# Early stopping at epoch 169
# Batch Size: 50, Train Loss: 0.239, Validation Loss: 0.275, Test RMSE: 0.519
# Testing batch size: 64
# Early stopping at epoch 119
# Batch Size: 64, Train Loss: 0.260, Validation Loss: 0.294, Test RMSE: 0.545
# Testing batch size: 128
# Early stopping at epoch 132
# Batch Size: 128, Train Loss: 0.271, Validation Loss: 0.300, Test RMSE: 0.534
# Testing batch size: 256
# Early stopping at epoch 147
# Batch Size: 256, Train Loss: 0.281, Validation Loss: 0.316, Test RMSE: 0.554
#    Batch Size  Train Loss  Validation Loss  Test RMSE
# 0          16    0.262786         0.293824   0.534579
# 1          32    0.276820         0.303396   0.535337
# 2          50    0.239093         0.275452   0.518706
# 3          64    0.259692         0.294168   0.544985
# 4         128    0.271176         0.299977   0.534124
# 5         256    0.280926         0.316467   0.553864
# Best Batch Size: 50.0 with Validation Loss: 0.275, Test RMSE: 0.519, Train Loss: 0.239

# %% [markdown]
# ### We will choose 50 as the batch size since it provided the lowest Validation Loss and Test RMSE.

# %%
set_seed(seed)
generator = torch.Generator()
generator.manual_seed(0)

batch_size = 50
train_dataset = TensorDataset(X_new_train, y_new_train)
train_iter = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

val_dataset = TensorDataset(X_val, y_val)
val_iter = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

# Architectures to test
architectures = [
    [8, 50, 1],
    [8, 100, 50, 1],
    [8, 64, 32, 16, 1],
    [8, 100, 50, 10, 1],
    [8, 32, 32, 16, 1]
]

# Function to create the model
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.normal_(m.weight, mean=0, std=0.01)  # Manual initialization of weights and bias for reproducability
        m.bias.data.fill_(0.0001)

def create_model(architecture):
    layers = []
    for i in range(len(architecture) - 1):
        layer = nn.Linear(architecture[i], architecture[i + 1])
        layers.append(layer)
        if i < len(architecture) - 2:
            layers.append(nn.ReLU())
    model = nn.Sequential(*layers)
    model.apply(init_weights)   
    return model

# Loss function
criterion = nn.MSELoss()

# Training function with early stopping and validation loss tracking
def train(model_inp, num_epochs=200, patience=40, print_interval=10):
    adjusted_lr = 0.0001 * (batch_size ** 0.5)
    optimizer = torch.optim.RMSprop(model_inp.parameters(), lr=adjusted_lr)
    
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    best_train_loss = None
    best_epoch = None
    epochs_without_improvement = 0  # Counter for early stopping
    
    # Loop through epochs
    for epoch in range(num_epochs):
        running_train_loss = 0.0
        model_inp.train()
        
        # Training loop
        for inputs, labels in train_iter:
            outputs = model_inp(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item()
        
        # Validation loop
        model_inp.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_iter:
                outputs = model_inp(inputs)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
        
        # Calculate the average losses
        avg_train_loss = running_train_loss / len(train_iter)
        avg_val_loss = running_val_loss / len(val_iter)
        
        # Store the losses
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # If validation loss improves, save model and update best loss
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_train_loss = avg_train_loss
            best_epoch = epoch
            epochs_without_improvement = 0  # Reset counter if validation loss improves
            
            # Save the model with the lowest validation loss
            save_model(model_inp, os.path.join(model_dir, f"best_model.pth"))
        else:
            epochs_without_improvement += 1
        
        # Early stopping condition
        if epochs_without_improvement >= patience:
            print(f"Early stopping at epoch {epoch + 1} due to no improvement in validation loss.")
            break

        # Print the best validation loss every `print_interval` epochs
        if (epoch + 1) % print_interval == 0:
            print(f"Epoch [{epoch + 1}/{num_epochs}] Train Loss: {avg_train_loss:.3f}, Validation Loss: {avg_val_loss:.3f}")
            print(f"Best Validation Loss: {best_val_loss:.3f} at Epoch {best_epoch + 1}")

    return train_losses, val_losses, best_train_loss, best_val_loss, best_epoch

# Save the model to the 'models' folder
def save_model(model_obj, model_path):
    torch.save(model_obj.state_dict(), model_path)

model_dir = "models"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

train_val_loss_data = []
best_loss_data = []

for idx, architecture in enumerate(architectures):
    print(f"\nTraining model {idx + 1} with architecture: {architecture}")

    # Create model
    model = create_model(architecture)
    model.train()
    
    # Train the model
    model_path = os.path.join(model_dir, f"model_architecture_{idx + 1}.pth")
    train_losses, val_losses, best_train_loss, best_val_loss_at_epoch, best_epoch = train(model, num_epochs=200)
    
    # Save the model
    save_model(model, model_path)
    
    # Collect the final train and validation loss
    for epoch in range(len(train_losses)):
        train_val_loss_data.append({
            'Model': f"Model_{idx + 1}",
            'Epoch': epoch + 1,  # Epoch starts from 1, not 0
            'Train Loss': train_losses[epoch],  # Loss for the current epoch
            'Validation Loss': val_losses[epoch]  # Validation loss for the current epoch
        })

    # Collect the best train loss, best validation loss, and best epoch
    best_loss_data.append({
        'Model': f"Model_{idx + 1}",
        'Best Train Loss': best_train_loss,
        'Best Validation Loss': best_val_loss_at_epoch,
        'Best Epoch': best_epoch
    })

    # Evaluate the model on the test set
    model.eval()
    with torch.no_grad():
        outputs = model(X_test)
        err = np.sqrt(mean_squared_error(outputs.numpy(), y_test.numpy()))
        print(f"Model {idx + 1} RMSE on test set: {err:.3f}")

train_val_loss_summary = pd.DataFrame(train_val_loss_data)
best_loss_summary = pd.DataFrame(best_loss_data)

# Display both summaries
print("\nTraining and Validation Loss Summary:")
print(train_val_loss_summary)

print("\nBest Loss and Epoch Summary:")
print(best_loss_summary)
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
#
# Training model 1 with architecture: [8, 50, 1]
# Epoch [10/200] Train Loss: 0.402, Validation Loss: 0.442
# Best Validation Loss: 0.435 at Epoch 9
# Epoch [20/200] Train Loss: 0.379, Validation Loss: 0.411
# Best Validation Loss: 0.411 at Epoch 20
# Epoch [30/200] Train Loss: 0.367, Validation Loss: 0.405
# Best Validation Loss: 0.398 at Epoch 29
# Epoch [40/200] Train Loss: 0.360, Validation Loss: 0.393
# Best Validation Loss: 0.393 at Epoch 40
# Epoch [50/200] Train Loss: 0.357, Validation Loss: 0.391
# Best Validation Loss: 0.390 at Epoch 45
# Epoch [60/200] Train Loss: 0.355, Validation Loss: 0.394
# Best Validation Loss: 0.389 at Epoch 56
# Epoch [70/200] Train Loss: 0.352, Validation Loss: 0.388
# Best Validation Loss: 0.384 at Epoch 68
# Epoch [80/200] Train Loss: 0.352, Validation Loss: 0.384
# Best Validation Loss: 0.383 at Epoch 75
# Epoch [90/200] Train Loss: 0.350, Validation Loss: 0.381
# Best Validation Loss: 0.381 at Epoch 90
# Epoch [100/200] Train Loss: 0.345, Validation Loss: 0.377
# Best Validation Loss: 0.376 at Epoch 99
# Epoch [110/200] Train Loss: 0.341, Validation Loss: 0.374
# Best Validation Loss: 0.373 at Epoch 109
# Epoch [120/200] Train Loss: 0.338, Validation Loss: 0.371
# Best Validation Loss: 0.369 at Epoch 118
# Epoch [130/200] Train Loss: 0.335, Validation Loss: 0.369
# Best Validation Loss: 0.367 at Epoch 128
# Epoch [140/200] Train Loss: 0.334, Validation Loss: 0.364
# Best Validation Loss: 0.364 at Epoch 140
# Epoch [150/200] Train Loss: 0.333, Validation Loss: 0.366
# Best Validation Loss: 0.364 at Epoch 143
# Epoch [160/200] Train Loss: 0.331, Validation Loss: 0.363
# Best Validation Loss: 0.363 at Epoch 160
# Epoch [170/200] Train Loss: 0.331, Validation Loss: 0.363
# Best Validation Loss: 0.361 at Epoch 169
# Epoch [180/200] Train Loss: 0.329, Validation Loss: 0.362
# Best Validation Loss: 0.360 at Epoch 176
# Epoch [190/200] Train Loss: 0.329, Validation Loss: 0.359
# Best Validation Loss: 0.359 at Epoch 186
# Epoch [200/200] Train Loss: 0.327, Validation Loss: 0.360
# Best Validation Loss: 0.358 at Epoch 195
# Model 1 RMSE on test set: 0.585
#
# Training model 2 with architecture: [8, 100, 50, 1]
# Epoch [10/200] Train Loss: 0.390, Validation Loss: 0.417
# Best Validation Loss: 0.417 at Epoch 10
# Epoch [20/200] Train Loss: 0.377, Validation Loss: 0.408
# Best Validation Loss: 0.408 at Epoch 20
# Epoch [30/200] Train Loss: 0.354, Validation Loss: 0.383
# Best Validation Loss: 0.383 at Epoch 30
# Epoch [40/200] Train Loss: 0.327, Validation Loss: 0.355
# Best Validation Loss: 0.355 at Epoch 40
# Epoch [50/200] Train Loss: 0.310, Validation Loss: 0.330
# Best Validation Loss: 0.330 at Epoch 50
# Epoch [60/200] Train Loss: 0.298, Validation Loss: 0.320
# Best Validation Loss: 0.320 at Epoch 60
# Epoch [70/200] Train Loss: 0.289, Validation Loss: 0.320
# Best Validation Loss: 0.320 at Epoch 67
# Epoch [80/200] Train Loss: 0.283, Validation Loss: 0.313
# Best Validation Loss: 0.313 at Epoch 80
# Epoch [90/200] Train Loss: 0.278, Validation Loss: 0.324
# Best Validation Loss: 0.310 at Epoch 87
# Epoch [100/200] Train Loss: 0.271, Validation Loss: 0.313
# Best Validation Loss: 0.303 at Epoch 96
# Epoch [110/200] Train Loss: 0.267, Validation Loss: 0.307
# Best Validation Loss: 0.302 at Epoch 105
# Epoch [120/200] Train Loss: 0.265, Validation Loss: 0.300
# Best Validation Loss: 0.292 at Epoch 115
# Epoch [130/200] Train Loss: 0.259, Validation Loss: 0.298
# Best Validation Loss: 0.292 at Epoch 115
# Epoch [140/200] Train Loss: 0.258, Validation Loss: 0.300
# Best Validation Loss: 0.289 at Epoch 131
# Epoch [150/200] Train Loss: 0.255, Validation Loss: 0.293
# Best Validation Loss: 0.289 at Epoch 131
# Epoch [160/200] Train Loss: 0.254, Validation Loss: 0.291
# Best Validation Loss: 0.285 at Epoch 152
# Epoch [170/200] Train Loss: 0.252, Validation Loss: 0.291
# Best Validation Loss: 0.285 at Epoch 152
# Epoch [180/200] Train Loss: 0.249, Validation Loss: 0.289
# Best Validation Loss: 0.283 at Epoch 179
# Epoch [190/200] Train Loss: 0.246, Validation Loss: 0.293
# Best Validation Loss: 0.282 at Epoch 184
# Epoch [200/200] Train Loss: 0.246, Validation Loss: 0.304
# Best Validation Loss: 0.280 at Epoch 191
# Model 2 RMSE on test set: 0.538
#
# Training model 3 with architecture: [8, 64, 32, 16, 1]
# Epoch [10/200] Train Loss: 0.393, Validation Loss: 0.433
# Best Validation Loss: 0.426 at Epoch 8
# Epoch [20/200] Train Loss: 0.381, Validation Loss: 0.410
# Best Validation Loss: 0.408 at Epoch 19
# Epoch [30/200] Train Loss: 0.374, Validation Loss: 0.404
# Best Validation Loss: 0.404 at Epoch 30
# Epoch [40/200] Train Loss: 0.345, Validation Loss: 0.373
# Best Validation Loss: 0.373 at Epoch 40
# Epoch [50/200] Train Loss: 0.330, Validation Loss: 0.364
# Best Validation Loss: 0.360 at Epoch 48
# Epoch [60/200] Train Loss: 0.320, Validation Loss: 0.362
# Best Validation Loss: 0.354 at Epoch 59
# Epoch [70/200] Train Loss: 0.305, Validation Loss: 0.342
# Best Validation Loss: 0.341 at Epoch 68
# Epoch [80/200] Train Loss: 0.296, Validation Loss: 0.330
# Best Validation Loss: 0.330 at Epoch 80
# Epoch [90/200] Train Loss: 0.290, Validation Loss: 0.324
# Best Validation Loss: 0.322 at Epoch 86
# Epoch [100/200] Train Loss: 0.282, Validation Loss: 0.318
# Best Validation Loss: 0.316 at Epoch 97
# Epoch [110/200] Train Loss: 0.276, Validation Loss: 0.312
# Best Validation Loss: 0.310 at Epoch 105
# Epoch [120/200] Train Loss: 0.273, Validation Loss: 0.307
# Best Validation Loss: 0.307 at Epoch 120
# Epoch [130/200] Train Loss: 0.270, Validation Loss: 0.301
# Best Validation Loss: 0.301 at Epoch 130
# Epoch [140/200] Train Loss: 0.261, Validation Loss: 0.301
# Best Validation Loss: 0.300 at Epoch 133
# Epoch [150/200] Train Loss: 0.255, Validation Loss: 0.299
# Best Validation Loss: 0.290 at Epoch 149
# Epoch [160/200] Train Loss: 0.252, Validation Loss: 0.293
# Best Validation Loss: 0.286 at Epoch 158
# Epoch [170/200] Train Loss: 0.255, Validation Loss: 0.295
# Best Validation Loss: 0.285 at Epoch 168
# Epoch [180/200] Train Loss: 0.243, Validation Loss: 0.284
# Best Validation Loss: 0.282 at Epoch 179
# Epoch [190/200] Train Loss: 0.242, Validation Loss: 0.281
# Best Validation Loss: 0.278 at Epoch 188
# Epoch [200/200] Train Loss: 0.241, Validation Loss: 0.287
# Best Validation Loss: 0.277 at Epoch 195
# Model 3 RMSE on test set: 0.531
#
# Training model 4 with architecture: [8, 100, 50, 10, 1]
# Epoch [10/200] Train Loss: 0.395, Validation Loss: 0.424
# Best Validation Loss: 0.424 at Epoch 10
# Epoch [20/200] Train Loss: 0.377, Validation Loss: 0.410
# Best Validation Loss: 0.410 at Epoch 19
# Epoch [30/200] Train Loss: 0.364, Validation Loss: 0.406
# Best Validation Loss: 0.393 at Epoch 29
# Epoch [40/200] Train Loss: 0.338, Validation Loss: 0.366
# Best Validation Loss: 0.366 at Epoch 40
# Epoch [50/200] Train Loss: 0.312, Validation Loss: 0.356
# Best Validation Loss: 0.341 at Epoch 48
# Epoch [60/200] Train Loss: 0.295, Validation Loss: 0.329
# Best Validation Loss: 0.324 at Epoch 59
# Epoch [70/200] Train Loss: 0.287, Validation Loss: 0.311
# Best Validation Loss: 0.311 at Epoch 70
# Epoch [80/200] Train Loss: 0.280, Validation Loss: 0.310
# Best Validation Loss: 0.308 at Epoch 72
# Epoch [90/200] Train Loss: 0.273, Validation Loss: 0.314
# Best Validation Loss: 0.304 at Epoch 89
# Epoch [100/200] Train Loss: 0.270, Validation Loss: 0.305
# Best Validation Loss: 0.297 at Epoch 98
# Epoch [110/200] Train Loss: 0.264, Validation Loss: 0.304
# Best Validation Loss: 0.296 at Epoch 109
# Epoch [120/200] Train Loss: 0.259, Validation Loss: 0.298
# Best Validation Loss: 0.295 at Epoch 119
# Epoch [130/200] Train Loss: 0.254, Validation Loss: 0.292
# Best Validation Loss: 0.292 at Epoch 130
# Epoch [140/200] Train Loss: 0.253, Validation Loss: 0.301
# Best Validation Loss: 0.289 at Epoch 138
# Epoch [150/200] Train Loss: 0.250, Validation Loss: 0.283
# Best Validation Loss: 0.283 at Epoch 150
# Epoch [160/200] Train Loss: 0.246, Validation Loss: 0.290
# Best Validation Loss: 0.283 at Epoch 150
# Epoch [170/200] Train Loss: 0.245, Validation Loss: 0.285
# Best Validation Loss: 0.279 at Epoch 169
# Epoch [180/200] Train Loss: 0.241, Validation Loss: 0.283
# Best Validation Loss: 0.279 at Epoch 169
# Epoch [190/200] Train Loss: 0.236, Validation Loss: 0.283
# Best Validation Loss: 0.278 at Epoch 181
# Epoch [200/200] Train Loss: 0.235, Validation Loss: 0.315
# Best Validation Loss: 0.278 at Epoch 181
# Model 4 RMSE on test set: 0.544
#
# Training model 5 with architecture: [8, 32, 32, 16, 1]
# Epoch [10/200] Train Loss: 0.394, Validation Loss: 0.431
# Best Validation Loss: 0.427 at Epoch 9
# Epoch [20/200] Train Loss: 0.373, Validation Loss: 0.410
# Best Validation Loss: 0.406 at Epoch 19
# Epoch [30/200] Train Loss: 0.359, Validation Loss: 0.390
# Best Validation Loss: 0.389 at Epoch 28
# Epoch [40/200] Train Loss: 0.347, Validation Loss: 0.378
# Best Validation Loss: 0.377 at Epoch 38
# Epoch [50/200] Train Loss: 0.331, Validation Loss: 0.361
# Best Validation Loss: 0.360 at Epoch 48
# Epoch [60/200] Train Loss: 0.314, Validation Loss: 0.343
# Best Validation Loss: 0.343 at Epoch 60
# Epoch [70/200] Train Loss: 0.305, Validation Loss: 0.337
# Best Validation Loss: 0.333 at Epoch 69
# Epoch [80/200] Train Loss: 0.298, Validation Loss: 0.330
# Best Validation Loss: 0.330 at Epoch 80
# Epoch [90/200] Train Loss: 0.295, Validation Loss: 0.322
# Best Validation Loss: 0.322 at Epoch 90
# Epoch [100/200] Train Loss: 0.293, Validation Loss: 0.321
# Best Validation Loss: 0.321 at Epoch 100
# Epoch [110/200] Train Loss: 0.288, Validation Loss: 0.317
# Best Validation Loss: 0.317 at Epoch 110
# Epoch [120/200] Train Loss: 0.288, Validation Loss: 0.329
# Best Validation Loss: 0.315 at Epoch 119
# Epoch [130/200] Train Loss: 0.284, Validation Loss: 0.316
# Best Validation Loss: 0.315 at Epoch 119
# Epoch [140/200] Train Loss: 0.282, Validation Loss: 0.323
# Best Validation Loss: 0.311 at Epoch 132
# Epoch [150/200] Train Loss: 0.280, Validation Loss: 0.319
# Best Validation Loss: 0.311 at Epoch 132
# Epoch [160/200] Train Loss: 0.278, Validation Loss: 0.307
# Best Validation Loss: 0.306 at Epoch 158
# Epoch [170/200] Train Loss: 0.272, Validation Loss: 0.304
# Best Validation Loss: 0.304 at Epoch 170
# Epoch [180/200] Train Loss: 0.271, Validation Loss: 0.306
# Best Validation Loss: 0.300 at Epoch 174
# Epoch [190/200] Train Loss: 0.267, Validation Loss: 0.316
# Best Validation Loss: 0.296 at Epoch 188
# Epoch [200/200] Train Loss: 0.264, Validation Loss: 0.297
# Best Validation Loss: 0.293 at Epoch 199
# Model 5 RMSE on test set: 0.530
#
# Training and Validation Loss Summary:
#        Model  Epoch  Train Loss  Validation Loss
# 0    Model_1      1    1.382063         0.658148
# 1    Model_1      2    0.535118         0.512938
# 2    Model_1      3    0.449388         0.471787
# 3    Model_1      4    0.428317         0.459749
# 4    Model_1      5    0.419563         0.451849
# ..       ...    ...         ...              ...
# 995  Model_5    196    0.265755         0.296452
# 996  Model_5    197    0.264544         0.312557
# 997  Model_5    198    0.264784         0.293819
# 998  Model_5    199    0.264134         0.292847
# 999  Model_5    200    0.264102         0.297292
#
# [1000 rows x 4 columns]
#
# Best Loss and Epoch Summary:
#      Model  Best Train Loss  Best Validation Loss  Best Epoch
# 0  Model_1         0.327237              0.358227         194
# 1  Model_2         0.247931              0.280148         190
# 2  Model_3         0.240074              0.277134         194
# 3  Model_4         0.240514              0.278426         180
# 4  Model_5         0.264134              0.292847         198

# %% [markdown]
# ### Chosen Architecture: `[8, 64, 32, 16, 1]` due to lowest validation loss
# This architecture represents a feedforward neural network with the following layers:
#
# - **Input Layer:** 8 neurons
# - **Hidden Layer 1:** 100 neurons
# - **Hidden Layer 2:** 50 neurons
# - **Hidden Layer 3:** 10 neurons
# - **Output Layer:** 1 neuron
#
# This structure defines the number of neurons in each layer, from the input to the output, with three hidden layers in between.
#
# It was chosen due to the lowest validation loss set of 0.279
#
# For the loss function we have used Mean Squared Error (MSE). The learning rate is adjusted depending on the batch size as follows: 0.0001 * (batch_size ** 0.5).
#
# For the activation function we have utilized ReLU. However, the output layer does not have an activation function, since we expect a continuous value in the regression task.

# %% [markdown]
# ### Task c)

# %%
set_seed(seed)
generator = torch.Generator()
generator.manual_seed(0)

# **Batch Size**
batch_size = 50

# **Number of Epochs**
num_epochs = 200

# **Architecture**
architecture = [8, 64, 32, 16, 1]

# Ensure the directory for saving models exists
model_save_dir = "models_optimizer"
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)

# Define the dataset and data loaders
train_dataset = TensorDataset(X_new_train, y_new_train)
train_iter = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

val_dataset = TensorDataset(X_val, y_val)
val_iter = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

# Function to create the model
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.normal_(m.weight, mean=0, std=0.01)  # Manual initialization of weights and bias for reproducability
        m.bias.data.fill_(0.0001)

def create_model(architecture):
    layers = []
    for i in range(len(architecture) - 1):
        layer = nn.Linear(architecture[i], architecture[i + 1])
        layers.append(layer)
        if i < len(architecture) - 2:
            layers.append(nn.ReLU())
    model = nn.Sequential(*layers)
    model.apply(init_weights)   
    return model

# Loss function
criterion = nn.MSELoss()

# Gradient clipping value
max_grad_norm = 5.0

# Define optimizers with multiple learning rates
optimizers = [
    {"name": "SGD", "optimizer": SGD, "params": {"lr": lr}}
    for lr in [1e-3, 1e-2, 1e-1]
] + [
    {"name": "SGD_Momentum", "optimizer": SGD, "params": {"lr": lr, "momentum": 0.9}}
    for lr in [1e-3, 1e-2, 1e-1]
] + [
    {"name": "Adam", "optimizer": Adam, "params": {"lr": lr}}
    for lr in [1e-3, 1e-2, 1e-1]
]

# Schedulers
schedulers = [
    {"name": "None", "scheduler": None, "params": {}},
    {"name": "StepLR", "scheduler": StepLR, "params": {"step_size": 10, "gamma": 0.1}},
    {"name": "ReduceLROnPlateau", "scheduler": ReduceLROnPlateau, "params": {"factor": 0.5, "patience": 5}},
]

# Early stopping function
class EarlyStopping:
    def __init__(self, patience=40, delta=0.001, save_path="best_model.pth"):
        """
        Initializes early stopping.
        Args:
        - patience (int): How many epochs to wait before stopping when no improvement.
        - delta (float): Minimum change in the monitored metric to qualify as improvement.
        - save_path (str): Path to save the best model.
        """
        self.patience = patience
        self.delta = delta
        self.save_path = save_path
        self.best_loss = float("inf")
        self.counter = 0
        self.early_stop = False
        self.best_epoch = 0  # Track the epoch of the best validation loss

    def __call__(self, val_loss, model, epoch):
        """
        Checks if training should stop.
        Args:
        - val_loss (float): Current validation loss.
        - model (nn.Module): The model to save when improvement occurs.
        - epoch (int): Current epoch number.
        """
        if val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.counter = 0
            self.best_epoch = epoch
            torch.save(model.state_dict(), self.save_path)
            print(f"Validation loss improved to {self.best_loss:.4f}. Saving model at epoch {epoch + 1}.")
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
                print(f"Early stopping triggered at epoch {epoch + 1}. Best validation loss was {self.best_loss:.4f} at epoch {self.best_epoch + 1}.")

# Training and validation function with best value tracking
def train_and_validate(
    model, train_iter, val_iter, num_epochs, optimizer_cls=None, optimizer_params=None, scheduler_cls=None, scheduler_params=None, early_stopping=None
):
    optimizer = optimizer_cls(model.parameters(), **optimizer_params)
    scheduler = scheduler_cls(optimizer, **scheduler_params) if scheduler_cls else None

    train_losses, val_losses = [], []

    # Initialize best values
    best_val_loss = float("inf")
    best_train_loss = None
    best_epoch = 0
    best_model_state = None  # To store the state dict of the best model

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_train_loss = 0.0
        for inputs, labels in train_iter:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
            optimizer.step()
            running_train_loss += loss.item()

        avg_train_loss = running_train_loss / len(train_iter)
        train_losses.append(avg_train_loss)

        # Validation phase
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_iter:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                if not torch.isfinite(loss):
                    print(f"NaN detected in validation loss at epoch {epoch + 1}. Skipping...")
                    loss = torch.tensor(float("inf"))  # Assign high loss value
                running_val_loss += loss.item()

        avg_val_loss = running_val_loss / len(val_iter)
        val_losses.append(avg_val_loss)

        # Update the best model and its state
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_train_loss = avg_train_loss
            best_epoch = epoch + 1
            best_model_state = model.state_dict()  # Save the best model state
            print(f"Validation loss improved to {best_val_loss:.4f} at epoch {epoch + 1}.")

        # Update scheduler if applicable
        if scheduler:
            if isinstance(scheduler, ReduceLROnPlateau):
                scheduler.step(avg_val_loss)
            else:
                scheduler.step()

        # Check early stopping
        if early_stopping:
            early_stopping(avg_val_loss, model, epoch)
            if early_stopping.early_stop:
                print(f"Early stopping triggered. Best validation loss: {best_val_loss:.4f}")
                break

        # Print intermediate results every 10 epochs
        if epoch % 10 == 0 or epoch == num_epochs - 1:
            print(f"Epoch {epoch + 1}/{num_epochs} - Train Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}")

    return train_losses, val_losses, best_train_loss, best_val_loss, best_epoch, best_model_state

# Run experiments for each optimizer and scheduler
results = []
for opt_config in optimizers:
    for sched_config in schedulers:
        print(f"=== Training with Optimizer: {opt_config['name']}, LR: {opt_config['params']['lr']}, Scheduler: {sched_config['name']} ===")
        model = create_model(architecture)
        
        # Initialize early stopping
        early_stopping = EarlyStopping(patience=20, delta=0.001)
        
        train_losses, val_losses, best_train_loss, best_val_loss, best_epoch, best_model_state = train_and_validate(
            model,
            train_iter,
            val_iter,
            num_epochs,
            optimizer_cls=opt_config["optimizer"],
            optimizer_params=opt_config["params"],
            scheduler_cls=sched_config["scheduler"],
            scheduler_params=sched_config["params"],
            early_stopping=early_stopping
        )
        print(f"Best Train Loss: {best_train_loss:.4f}, Best Validation Loss: {best_val_loss:.4f} at Epoch {best_epoch}\n")
        
        # Save the best model state to a file
        model_save_path = f"{model_save_dir}/best_model_{opt_config['name']}_LR{opt_config['params']['lr']}_{sched_config['name']}.pth"
        torch.save(best_model_state, model_save_path)
        print(f"Best model saved to {model_save_path}")

        # Save results
        results.append({
            "Optimizer": opt_config["name"],
            "Learning Rate": opt_config["params"]["lr"],
            "Scheduler": sched_config["name"],
            "Best Train Loss": best_train_loss,
            "Best Val Loss": best_val_loss,
            "Best Epoch": best_epoch,
            "Model Path": model_save_path
        })

# Store results in a DataFrame
results_df = pd.DataFrame(results)

# Save results as a CSV file
results_csv_path = os.path.join(model_save_dir, "results_summary.csv")
results_df.to_csv(results_csv_path, index=False)

# Display the final results
print("=== Optimizer and Scheduler Comparison Results ===")
print(results_df)
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
# === Training with Optimizer: SGD, LR: 0.001, Scheduler: None ===
# Validation loss improved to 3.0233 at epoch 1.
# Validation loss improved to 3.0233. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 4.0307, Validation Loss: 3.0233
# Validation loss improved to 2.0033 at epoch 2.
# Validation loss improved to 2.0033. Saving model at epoch 2.
# Validation loss improved to 1.6176 at epoch 3.
# Validation loss improved to 1.6176. Saving model at epoch 3.
# Validation loss improved to 1.4700 at epoch 4.
# Validation loss improved to 1.4700. Saving model at epoch 4.
# Validation loss improved to 1.4123 at epoch 5.
# Validation loss improved to 1.4123. Saving model at epoch 5.
# Validation loss improved to 1.3898 at epoch 6.
# Validation loss improved to 1.3898. Saving model at epoch 6.
# Validation loss improved to 1.3805 at epoch 7.
# Validation loss improved to 1.3805. Saving model at epoch 7.
# Validation loss improved to 1.3764 at epoch 8.
# Validation loss improved to 1.3764. Saving model at epoch 8.
# Validation loss improved to 1.3743 at epoch 9.
# Validation loss improved to 1.3743. Saving model at epoch 9.
# Validation loss improved to 1.3734 at epoch 10.
# Validation loss improved to 1.3729 at epoch 11.
# Validation loss improved to 1.3729. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 1.3299, Validation Loss: 1.3729
# Validation loss improved to 1.3726 at epoch 12.
# Validation loss improved to 1.3725 at epoch 13.
# Validation loss improved to 1.3725 at epoch 14.
# Validation loss improved to 1.3723 at epoch 15.
# Validation loss improved to 1.3723 at epoch 16.
# Validation loss improved to 1.3723 at epoch 18.
# Validation loss improved to 1.3723 at epoch 19.
# Epoch 21/200 - Train Loss: 1.3292, Validation Loss: 1.3724
# Early stopping triggered at epoch 31. Best validation loss was 1.3729 at epoch 11.
# Early stopping triggered. Best validation loss: 1.3723
# Best Train Loss: 1.3304, Best Validation Loss: 1.3723 at Epoch 19
#
# Best model saved to models_optimizer/best_model_SGD_LR0.001_None.pth
# === Training with Optimizer: SGD, LR: 0.001, Scheduler: StepLR ===
# Validation loss improved to 3.0207 at epoch 1.
# Validation loss improved to 3.0207. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 4.0292, Validation Loss: 3.0207
# Validation loss improved to 1.9978 at epoch 2.
# Validation loss improved to 1.9978. Saving model at epoch 2.
# Validation loss improved to 1.6128 at epoch 3.
# Validation loss improved to 1.6128. Saving model at epoch 3.
# Validation loss improved to 1.4670 at epoch 4.
# Validation loss improved to 1.4670. Saving model at epoch 4.
# Validation loss improved to 1.4108 at epoch 5.
# Validation loss improved to 1.4108. Saving model at epoch 5.
# Validation loss improved to 1.3886 at epoch 6.
# Validation loss improved to 1.3886. Saving model at epoch 6.
# Validation loss improved to 1.3796 at epoch 7.
# Validation loss improved to 1.3796. Saving model at epoch 7.
# Validation loss improved to 1.3758 at epoch 8.
# Validation loss improved to 1.3758. Saving model at epoch 8.
# Validation loss improved to 1.3740 at epoch 9.
# Validation loss improved to 1.3740. Saving model at epoch 9.
# Validation loss improved to 1.3732 at epoch 10.
# Validation loss improved to 1.3732 at epoch 11.
# Epoch 11/200 - Train Loss: 1.3306, Validation Loss: 1.3732
# Validation loss improved to 1.3731 at epoch 12.
# Validation loss improved to 1.3731 at epoch 13.
# Validation loss improved to 1.3730 at epoch 14.
# Validation loss improved to 1.3730 at epoch 15.
# Validation loss improved to 1.3730. Saving model at epoch 15.
# Validation loss improved to 1.3729 at epoch 16.
# Validation loss improved to 1.3729 at epoch 17.
# Validation loss improved to 1.3729 at epoch 18.
# Validation loss improved to 1.3728 at epoch 19.
# Validation loss improved to 1.3728 at epoch 20.
# Validation loss improved to 1.3728 at epoch 21.
# Epoch 21/200 - Train Loss: 1.3302, Validation Loss: 1.3728
# Validation loss improved to 1.3728 at epoch 22.
# Validation loss improved to 1.3728 at epoch 23.
# Validation loss improved to 1.3728 at epoch 24.
# Validation loss improved to 1.3728 at epoch 25.
# Validation loss improved to 1.3728 at epoch 26.
# Validation loss improved to 1.3728 at epoch 27.
# Validation loss improved to 1.3728 at epoch 28.
# Validation loss improved to 1.3728 at epoch 29.
# Validation loss improved to 1.3728 at epoch 30.
# Validation loss improved to 1.3728 at epoch 31.
# Epoch 31/200 - Train Loss: 1.3306, Validation Loss: 1.3728
# Validation loss improved to 1.3728 at epoch 32.
# Validation loss improved to 1.3728 at epoch 33.
# Validation loss improved to 1.3728 at epoch 34.
# Validation loss improved to 1.3728 at epoch 35.
# Early stopping triggered at epoch 35. Best validation loss was 1.3730 at epoch 15.
# Early stopping triggered. Best validation loss: 1.3728
# Best Train Loss: 1.3301, Best Validation Loss: 1.3728 at Epoch 35
#
# Best model saved to models_optimizer/best_model_SGD_LR0.001_StepLR.pth
# === Training with Optimizer: SGD, LR: 0.001, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 3.0203 at epoch 1.
# Validation loss improved to 3.0203. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 4.0304, Validation Loss: 3.0203
# Validation loss improved to 2.0007 at epoch 2.
# Validation loss improved to 2.0007. Saving model at epoch 2.
# Validation loss improved to 1.6160 at epoch 3.
# Validation loss improved to 1.6160. Saving model at epoch 3.
# Validation loss improved to 1.4684 at epoch 4.
# Validation loss improved to 1.4684. Saving model at epoch 4.
# Validation loss improved to 1.4118 at epoch 5.
# Validation loss improved to 1.4118. Saving model at epoch 5.
# Validation loss improved to 1.3894 at epoch 6.
# Validation loss improved to 1.3894. Saving model at epoch 6.
# Validation loss improved to 1.3801 at epoch 7.
# Validation loss improved to 1.3801. Saving model at epoch 7.
# Validation loss improved to 1.3761 at epoch 8.
# Validation loss improved to 1.3761. Saving model at epoch 8.
# Validation loss improved to 1.3743 at epoch 9.
# Validation loss improved to 1.3743. Saving model at epoch 9.
# Validation loss improved to 1.3735 at epoch 10.
# Validation loss improved to 1.3729 at epoch 11.
# Validation loss improved to 1.3729. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 1.3306, Validation Loss: 1.3729
# Validation loss improved to 1.3726 at epoch 12.
# Validation loss improved to 1.3725 at epoch 13.
# Validation loss improved to 1.3725 at epoch 14.
# Validation loss improved to 1.3724 at epoch 16.
# Validation loss improved to 1.3723 at epoch 17.
# Validation loss improved to 1.3723 at epoch 18.
# Validation loss improved to 1.3722 at epoch 21.
# Epoch 21/200 - Train Loss: 1.3311, Validation Loss: 1.3722
# Early stopping triggered at epoch 31. Best validation loss was 1.3729 at epoch 11.
# Early stopping triggered. Best validation loss: 1.3722
# Best Train Loss: 1.3311, Best Validation Loss: 1.3722 at Epoch 21
#
# Best model saved to models_optimizer/best_model_SGD_LR0.001_ReduceLROnPlateau.pth
# === Training with Optimizer: SGD, LR: 0.01, Scheduler: None ===
# Validation loss improved to 1.3731 at epoch 1.
# Validation loss improved to 1.3731. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.7647, Validation Loss: 1.3731
# Validation loss improved to 1.3715 at epoch 2.
# Validation loss improved to 1.3715. Saving model at epoch 2.
# Validation loss improved to 1.3714 at epoch 8.
# Epoch 11/200 - Train Loss: 1.3299, Validation Loss: 1.3715
# Validation loss improved to 1.3714 at epoch 12.
# Validation loss improved to 1.3714 at epoch 20.
# Epoch 21/200 - Train Loss: 1.3302, Validation Loss: 1.3718
# Early stopping triggered at epoch 22. Best validation loss was 1.3715 at epoch 2.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3297, Best Validation Loss: 1.3714 at Epoch 20
#
# Best model saved to models_optimizer/best_model_SGD_LR0.01_None.pth
# === Training with Optimizer: SGD, LR: 0.01, Scheduler: StepLR ===
# Validation loss improved to 1.3719 at epoch 1.
# Validation loss improved to 1.3719. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.7606, Validation Loss: 1.3719
# Validation loss improved to 1.3716 at epoch 2.
# Validation loss improved to 1.3714 at epoch 8.
# Epoch 11/200 - Train Loss: 1.3304, Validation Loss: 1.3723
# Early stopping triggered at epoch 21. Best validation loss was 1.3719 at epoch 1.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3307, Best Validation Loss: 1.3714 at Epoch 8
#
# Best model saved to models_optimizer/best_model_SGD_LR0.01_StepLR.pth
# === Training with Optimizer: SGD, LR: 0.01, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 1.3731 at epoch 1.
# Validation loss improved to 1.3731. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.7579, Validation Loss: 1.3731
# Validation loss improved to 1.3722 at epoch 2.
# Validation loss improved to 1.3720 at epoch 3.
# Validation loss improved to 1.3720. Saving model at epoch 3.
# Validation loss improved to 1.3715 at epoch 9.
# Epoch 11/200 - Train Loss: 1.3309, Validation Loss: 1.3728
# Validation loss improved to 1.3714 at epoch 13.
# Validation loss improved to 1.3714 at epoch 14.
# Epoch 21/200 - Train Loss: 1.3294, Validation Loss: 1.3719
# Early stopping triggered at epoch 23. Best validation loss was 1.3720 at epoch 3.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3292, Best Validation Loss: 1.3714 at Epoch 14
#
# Best model saved to models_optimizer/best_model_SGD_LR0.01_ReduceLROnPlateau.pth
# === Training with Optimizer: SGD, LR: 0.1, Scheduler: None ===
# Validation loss improved to 1.3714 at epoch 1.
# Validation loss improved to 1.3714. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.3807, Validation Loss: 1.3714
# Validation loss improved to 1.3672 at epoch 8.
# Validation loss improved to 1.3672. Saving model at epoch 8.
# Validation loss improved to 0.9986 at epoch 9.
# Validation loss improved to 0.9986. Saving model at epoch 9.
# Validation loss improved to 0.5402 at epoch 10.
# Validation loss improved to 0.5402. Saving model at epoch 10.
# Validation loss improved to 0.4781 at epoch 11.
# Validation loss improved to 0.4781. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 0.4647, Validation Loss: 0.4781
# Validation loss improved to 0.4367 at epoch 14.
# Validation loss improved to 0.4367. Saving model at epoch 14.
# Validation loss improved to 0.4043 at epoch 15.
# Validation loss improved to 0.4043. Saving model at epoch 15.
# Validation loss improved to 0.3754 at epoch 18.
# Validation loss improved to 0.3754. Saving model at epoch 18.
# Validation loss improved to 0.3748 at epoch 21.
# Epoch 21/200 - Train Loss: 0.3678, Validation Loss: 0.3748
# Validation loss improved to 0.3556 at epoch 22.
# Validation loss improved to 0.3556. Saving model at epoch 22.
# Validation loss improved to 0.3468 at epoch 25.
# Validation loss improved to 0.3468. Saving model at epoch 25.
# Validation loss improved to 0.3442 at epoch 29.
# Validation loss improved to 0.3442. Saving model at epoch 29.
# Validation loss improved to 0.3408 at epoch 30.
# Validation loss improved to 0.3408. Saving model at epoch 30.
# Epoch 31/200 - Train Loss: 0.3262, Validation Loss: 0.3811
# Validation loss improved to 0.3294 at epoch 39.
# Validation loss improved to 0.3294. Saving model at epoch 39.
# Validation loss improved to 0.3274 at epoch 40.
# Validation loss improved to 0.3274. Saving model at epoch 40.
# Epoch 41/200 - Train Loss: 0.3104, Validation Loss: 0.3303
# Validation loss improved to 0.3138 at epoch 42.
# Validation loss improved to 0.3138. Saving model at epoch 42.
# Validation loss improved to 0.3093 at epoch 43.
# Validation loss improved to 0.3093. Saving model at epoch 43.
# Validation loss improved to 0.3056 at epoch 49.
# Validation loss improved to 0.3056. Saving model at epoch 49.
# Epoch 51/200 - Train Loss: 0.3061, Validation Loss: 0.3441
# Validation loss improved to 0.3030 at epoch 58.
# Validation loss improved to 0.3030. Saving model at epoch 58.
# Epoch 61/200 - Train Loss: 0.2895, Validation Loss: 0.3494
# Validation loss improved to 0.3008 at epoch 63.
# Validation loss improved to 0.3008. Saving model at epoch 63.
# Validation loss improved to 0.2988 at epoch 68.
# Validation loss improved to 0.2988. Saving model at epoch 68.
# Validation loss improved to 0.2980 at epoch 69.
# Epoch 71/200 - Train Loss: 0.2765, Validation Loss: 0.3163
# Validation loss improved to 0.2876 at epoch 73.
# Validation loss improved to 0.2876. Saving model at epoch 73.
# Epoch 81/200 - Train Loss: 0.2689, Validation Loss: 0.3053
# Validation loss improved to 0.2874 at epoch 83.
# Validation loss improved to 0.2874 at epoch 84.
# Validation loss improved to 0.2864 at epoch 89.
# Validation loss improved to 0.2864. Saving model at epoch 89.
# Epoch 91/200 - Train Loss: 0.2625, Validation Loss: 0.3683
# Epoch 101/200 - Train Loss: 0.2568, Validation Loss: 0.3164
# Validation loss improved to 0.2846 at epoch 104.
# Validation loss improved to 0.2846. Saving model at epoch 104.
# Epoch 111/200 - Train Loss: 0.2538, Validation Loss: 0.3083
# Validation loss improved to 0.2837 at epoch 113.
# Epoch 121/200 - Train Loss: 0.2433, Validation Loss: 0.4431
# Validation loss improved to 0.2832 at epoch 124.
# Validation loss improved to 0.2832. Saving model at epoch 124.
# Validation loss improved to 0.2826 at epoch 131.
# Epoch 131/200 - Train Loss: 0.2407, Validation Loss: 0.2826
# Epoch 141/200 - Train Loss: 0.2349, Validation Loss: 0.3154
# Validation loss improved to 0.2811 at epoch 142.
# Validation loss improved to 0.2811. Saving model at epoch 142.
# Epoch 151/200 - Train Loss: 0.2325, Validation Loss: 0.3026
# Validation loss improved to 0.2760 at epoch 152.
# Validation loss improved to 0.2760. Saving model at epoch 152.
# Epoch 161/200 - Train Loss: 0.2316, Validation Loss: 0.2884
# Validation loss improved to 0.2760 at epoch 166.
# Validation loss improved to 0.2723 at epoch 167.
# Validation loss improved to 0.2723. Saving model at epoch 167.
# Epoch 171/200 - Train Loss: 0.2219, Validation Loss: 0.2792
# Epoch 181/200 - Train Loss: 0.3758, Validation Loss: 0.2915
# Early stopping triggered at epoch 187. Best validation loss was 0.2723 at epoch 167.
# Early stopping triggered. Best validation loss: 0.2723
# Best Train Loss: 0.2201, Best Validation Loss: 0.2723 at Epoch 167
#
# Best model saved to models_optimizer/best_model_SGD_LR0.1_None.pth
# === Training with Optimizer: SGD, LR: 0.1, Scheduler: StepLR ===
# Validation loss improved to 1.3739 at epoch 1.
# Validation loss improved to 1.3739. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.3853, Validation Loss: 1.3739
# Validation loss improved to 1.3715 at epoch 3.
# Validation loss improved to 1.3715. Saving model at epoch 3.
# Validation loss improved to 1.3606 at epoch 7.
# Validation loss improved to 1.3606. Saving model at epoch 7.
# Validation loss improved to 0.5376 at epoch 8.
# Validation loss improved to 0.5376. Saving model at epoch 8.
# Validation loss improved to 0.5165 at epoch 9.
# Validation loss improved to 0.5165. Saving model at epoch 9.
# Validation loss improved to 0.4627 at epoch 10.
# Validation loss improved to 0.4627. Saving model at epoch 10.
# Validation loss improved to 0.4164 at epoch 11.
# Validation loss improved to 0.4164. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 0.3914, Validation Loss: 0.4164
# Validation loss improved to 0.4112 at epoch 12.
# Validation loss improved to 0.4112. Saving model at epoch 12.
# Validation loss improved to 0.4096 at epoch 13.
# Validation loss improved to 0.4096. Saving model at epoch 13.
# Validation loss improved to 0.4064 at epoch 14.
# Validation loss improved to 0.4064. Saving model at epoch 14.
# Validation loss improved to 0.4029 at epoch 15.
# Validation loss improved to 0.4029. Saving model at epoch 15.
# Validation loss improved to 0.3978 at epoch 17.
# Validation loss improved to 0.3978. Saving model at epoch 17.
# Validation loss improved to 0.3930 at epoch 18.
# Validation loss improved to 0.3930. Saving model at epoch 18.
# Validation loss improved to 0.3908 at epoch 19.
# Validation loss improved to 0.3908. Saving model at epoch 19.
# Validation loss improved to 0.3878 at epoch 20.
# Validation loss improved to 0.3878. Saving model at epoch 20.
# Validation loss improved to 0.3866 at epoch 21.
# Validation loss improved to 0.3866. Saving model at epoch 21.
# Epoch 21/200 - Train Loss: 0.3572, Validation Loss: 0.3866
# Validation loss improved to 0.3859 at epoch 22.
# Validation loss improved to 0.3854 at epoch 23.
# Validation loss improved to 0.3854. Saving model at epoch 23.
# Validation loss improved to 0.3852 at epoch 24.
# Validation loss improved to 0.3851 at epoch 25.
# Validation loss improved to 0.3846 at epoch 26.
# Validation loss improved to 0.3842 at epoch 27.
# Validation loss improved to 0.3842. Saving model at epoch 27.
# Validation loss improved to 0.3842 at epoch 28.
# Validation loss improved to 0.3837 at epoch 29.
# Validation loss improved to 0.3834 at epoch 30.
# Validation loss improved to 0.3833 at epoch 31.
# Epoch 31/200 - Train Loss: 0.3539, Validation Loss: 0.3833
# Validation loss improved to 0.3833 at epoch 32.
# Validation loss improved to 0.3833 at epoch 33.
# Validation loss improved to 0.3833 at epoch 34.
# Validation loss improved to 0.3833 at epoch 35.
# Validation loss improved to 0.3832 at epoch 36.
# Validation loss improved to 0.3832 at epoch 37.
# Validation loss improved to 0.3832 at epoch 38.
# Validation loss improved to 0.3832 at epoch 39.
# Validation loss improved to 0.3832. Saving model at epoch 39.
# Validation loss improved to 0.3832 at epoch 40.
# Validation loss improved to 0.3831 at epoch 41.
# Epoch 41/200 - Train Loss: 0.3534, Validation Loss: 0.3831
# Validation loss improved to 0.3831 at epoch 42.
# Validation loss improved to 0.3831 at epoch 43.
# Validation loss improved to 0.3831 at epoch 44.
# Validation loss improved to 0.3831 at epoch 45.
# Validation loss improved to 0.3831 at epoch 46.
# Validation loss improved to 0.3831 at epoch 47.
# Validation loss improved to 0.3831 at epoch 48.
# Validation loss improved to 0.3831 at epoch 49.
# Validation loss improved to 0.3831 at epoch 50.
# Validation loss improved to 0.3831 at epoch 51.
# Epoch 51/200 - Train Loss: 0.3536, Validation Loss: 0.3831
# Validation loss improved to 0.3831 at epoch 52.
# Validation loss improved to 0.3831 at epoch 53.
# Validation loss improved to 0.3831 at epoch 54.
# Validation loss improved to 0.3831 at epoch 55.
# Validation loss improved to 0.3831 at epoch 56.
# Validation loss improved to 0.3831 at epoch 57.
# Validation loss improved to 0.3831 at epoch 58.
# Validation loss improved to 0.3831 at epoch 59.
# Early stopping triggered at epoch 59. Best validation loss was 0.3832 at epoch 39.
# Early stopping triggered. Best validation loss: 0.3831
# Best Train Loss: 0.3535, Best Validation Loss: 0.3831 at Epoch 59
#
# Best model saved to models_optimizer/best_model_SGD_LR0.1_StepLR.pth
# === Training with Optimizer: SGD, LR: 0.1, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 1.3715 at epoch 1.
# Validation loss improved to 1.3715. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.3807, Validation Loss: 1.3715
# Validation loss improved to 1.3714 at epoch 3.
# Validation loss improved to 1.3641 at epoch 5.
# Validation loss improved to 1.3641. Saving model at epoch 5.
# Validation loss improved to 0.5646 at epoch 6.
# Validation loss improved to 0.5646. Saving model at epoch 6.
# Validation loss improved to 0.5499 at epoch 7.
# Validation loss improved to 0.5499. Saving model at epoch 7.
# Validation loss improved to 0.5133 at epoch 8.
# Validation loss improved to 0.5133. Saving model at epoch 8.
# Validation loss improved to 0.4755 at epoch 9.
# Validation loss improved to 0.4755. Saving model at epoch 9.
# Validation loss improved to 0.4115 at epoch 10.
# Validation loss improved to 0.4115. Saving model at epoch 10.
# Epoch 11/200 - Train Loss: 0.4201, Validation Loss: 0.4221
# Validation loss improved to 0.3781 at epoch 16.
# Validation loss improved to 0.3781. Saving model at epoch 16.
# Validation loss improved to 0.3616 at epoch 19.
# Validation loss improved to 0.3616. Saving model at epoch 19.
# Validation loss improved to 0.3513 at epoch 20.
# Validation loss improved to 0.3513. Saving model at epoch 20.
# Epoch 21/200 - Train Loss: 0.3597, Validation Loss: 0.3734
# Validation loss improved to 0.3391 at epoch 27.
# Validation loss improved to 0.3391. Saving model at epoch 27.
# Validation loss improved to 0.3159 at epoch 28.
# Validation loss improved to 0.3159. Saving model at epoch 28.
# Epoch 31/200 - Train Loss: 0.2965, Validation Loss: 0.3186
# Validation loss improved to 0.3120 at epoch 33.
# Validation loss improved to 0.3120. Saving model at epoch 33.
# Validation loss improved to 0.3091 at epoch 36.
# Validation loss improved to 0.3091. Saving model at epoch 36.
# Validation loss improved to 0.3063 at epoch 37.
# Validation loss improved to 0.3063. Saving model at epoch 37.
# Validation loss improved to 0.3032 at epoch 38.
# Validation loss improved to 0.3032. Saving model at epoch 38.
# Epoch 41/200 - Train Loss: 0.2821, Validation Loss: 0.3096
# Validation loss improved to 0.3029 at epoch 43.
# Validation loss improved to 0.2999 at epoch 45.
# Validation loss improved to 0.2999. Saving model at epoch 45.
# Validation loss improved to 0.2957 at epoch 50.
# Validation loss improved to 0.2957. Saving model at epoch 50.
# Epoch 51/200 - Train Loss: 0.2713, Validation Loss: 0.3588
# Validation loss improved to 0.2934 at epoch 53.
# Validation loss improved to 0.2934. Saving model at epoch 53.
# Validation loss improved to 0.2882 at epoch 57.
# Validation loss improved to 0.2882. Saving model at epoch 57.
# Epoch 61/200 - Train Loss: 0.2668, Validation Loss: 0.3081
# Validation loss improved to 0.2866 at epoch 65.
# Validation loss improved to 0.2866. Saving model at epoch 65.
# Validation loss improved to 0.2866 at epoch 68.
# Validation loss improved to 0.2860 at epoch 70.
# Validation loss improved to 0.2853 at epoch 71.
# Validation loss improved to 0.2853. Saving model at epoch 71.
# Epoch 71/200 - Train Loss: 0.2484, Validation Loss: 0.2853
# Validation loss improved to 0.2835 at epoch 72.
# Validation loss improved to 0.2835. Saving model at epoch 72.
# Validation loss improved to 0.2811 at epoch 76.
# Validation loss improved to 0.2811. Saving model at epoch 76.
# Validation loss improved to 0.2778 at epoch 81.
# Validation loss improved to 0.2778. Saving model at epoch 81.
# Epoch 81/200 - Train Loss: 0.2436, Validation Loss: 0.2778
# Validation loss improved to 0.2775 at epoch 83.
# Epoch 91/200 - Train Loss: 0.2334, Validation Loss: 0.2787
# Validation loss improved to 0.2753 at epoch 92.
# Validation loss improved to 0.2753. Saving model at epoch 92.
# Validation loss improved to 0.2746 at epoch 96.
# Epoch 101/200 - Train Loss: 0.2315, Validation Loss: 0.2784
# Validation loss improved to 0.2744 at epoch 104.
# Validation loss improved to 0.2741 at epoch 106.
# Validation loss improved to 0.2741. Saving model at epoch 106.
# Epoch 111/200 - Train Loss: 0.2279, Validation Loss: 0.2752
# Validation loss improved to 0.2736 at epoch 113.
# Validation loss improved to 0.2734 at epoch 119.
# Epoch 121/200 - Train Loss: 0.2256, Validation Loss: 0.2735
# Early stopping triggered at epoch 126. Best validation loss was 0.2741 at epoch 106.
# Early stopping triggered. Best validation loss: 0.2734
# Best Train Loss: 0.2255, Best Validation Loss: 0.2734 at Epoch 119
#
# Best model saved to models_optimizer/best_model_SGD_LR0.1_ReduceLROnPlateau.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.001, Scheduler: None ===
# Validation loss improved to 1.3717 at epoch 1.
# Validation loss improved to 1.3717. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.8186, Validation Loss: 1.3717
# Validation loss improved to 1.3715 at epoch 4.
# Epoch 11/200 - Train Loss: 1.3310, Validation Loss: 1.3729
# Validation loss improved to 1.3714 at epoch 14.
# Early stopping triggered at epoch 21. Best validation loss was 1.3717 at epoch 1.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3293, Best Validation Loss: 1.3714 at Epoch 14
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.001_None.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.001, Scheduler: StepLR ===
# Validation loss improved to 1.3732 at epoch 1.
# Validation loss improved to 1.3732. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.8403, Validation Loss: 1.3732
# Validation loss improved to 1.3716 at epoch 2.
# Validation loss improved to 1.3716. Saving model at epoch 2.
# Epoch 11/200 - Train Loss: 1.3302, Validation Loss: 1.3721
# Epoch 21/200 - Train Loss: 1.3300, Validation Loss: 1.3723
# Early stopping triggered at epoch 22. Best validation loss was 1.3716 at epoch 2.
# Early stopping triggered. Best validation loss: 1.3716
# Best Train Loss: 1.3300, Best Validation Loss: 1.3716 at Epoch 2
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.001_StepLR.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.001, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 1.3727 at epoch 1.
# Validation loss improved to 1.3727. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.8356, Validation Loss: 1.3727
# Validation loss improved to 1.3725 at epoch 2.
# Validation loss improved to 1.3723 at epoch 3.
# Validation loss improved to 1.3721 at epoch 9.
# Validation loss improved to 1.3718 at epoch 10.
# Validation loss improved to 1.3716 at epoch 11.
# Validation loss improved to 1.3716. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 1.3298, Validation Loss: 1.3716
# Validation loss improved to 1.3714 at epoch 15.
# Epoch 21/200 - Train Loss: 1.3299, Validation Loss: 1.3745
# Early stopping triggered at epoch 31. Best validation loss was 1.3716 at epoch 11.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3297, Best Validation Loss: 1.3714 at Epoch 15
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.001_ReduceLROnPlateau.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.01, Scheduler: None ===
# Validation loss improved to 1.3719 at epoch 1.
# Validation loss improved to 1.3719. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4526, Validation Loss: 1.3719
# Validation loss improved to 1.3714 at epoch 3.
# Epoch 11/200 - Train Loss: 1.3342, Validation Loss: 1.3762
# Validation loss improved to 0.5260 at epoch 14.
# Validation loss improved to 0.5260. Saving model at epoch 14.
# Validation loss improved to 0.4489 at epoch 15.
# Validation loss improved to 0.4489. Saving model at epoch 15.
# Validation loss improved to 0.4307 at epoch 16.
# Validation loss improved to 0.4307. Saving model at epoch 16.
# Validation loss improved to 0.3993 at epoch 17.
# Validation loss improved to 0.3993. Saving model at epoch 17.
# Validation loss improved to 0.3727 at epoch 20.
# Validation loss improved to 0.3727. Saving model at epoch 20.
# Epoch 21/200 - Train Loss: 0.3554, Validation Loss: 0.3767
# Validation loss improved to 0.3628 at epoch 22.
# Validation loss improved to 0.3628. Saving model at epoch 22.
# Validation loss improved to 0.3445 at epoch 24.
# Validation loss improved to 0.3445. Saving model at epoch 24.
# Validation loss improved to 0.3281 at epoch 27.
# Validation loss improved to 0.3281. Saving model at epoch 27.
# Validation loss improved to 0.3189 at epoch 31.
# Validation loss improved to 0.3189. Saving model at epoch 31.
# Epoch 31/200 - Train Loss: 0.3177, Validation Loss: 0.3189
# Validation loss improved to 0.3176 at epoch 35.
# Validation loss improved to 0.3176. Saving model at epoch 35.
# Validation loss improved to 0.3057 at epoch 37.
# Validation loss improved to 0.3057. Saving model at epoch 37.
# Epoch 41/200 - Train Loss: 0.2913, Validation Loss: 0.3439
# Validation loss improved to 0.3005 at epoch 43.
# Validation loss improved to 0.3005. Saving model at epoch 43.
# Validation loss improved to 0.2989 at epoch 46.
# Validation loss improved to 0.2989. Saving model at epoch 46.
# Validation loss improved to 0.2986 at epoch 49.
# Validation loss improved to 0.2950 at epoch 51.
# Validation loss improved to 0.2950. Saving model at epoch 51.
# Epoch 51/200 - Train Loss: 0.2719, Validation Loss: 0.2950
# Validation loss improved to 0.2901 at epoch 58.
# Validation loss improved to 0.2901. Saving model at epoch 58.
# Validation loss improved to 0.2879 at epoch 59.
# Validation loss improved to 0.2879. Saving model at epoch 59.
# Epoch 61/200 - Train Loss: 0.2659, Validation Loss: 0.3052
# Validation loss improved to 0.2851 at epoch 67.
# Validation loss improved to 0.2851. Saving model at epoch 67.
# Validation loss improved to 0.2809 at epoch 70.
# Validation loss improved to 0.2809. Saving model at epoch 70.
# Epoch 71/200 - Train Loss: 0.2543, Validation Loss: 0.2913
# Epoch 81/200 - Train Loss: 0.2576, Validation Loss: 0.2979
# Validation loss improved to 0.2802 at epoch 82.
# Validation loss improved to 0.2788 at epoch 84.
# Validation loss improved to 0.2788. Saving model at epoch 84.
# Validation loss improved to 0.2779 at epoch 85.
# Epoch 91/200 - Train Loss: 0.2453, Validation Loss: 0.2955
# Validation loss improved to 0.2713 at epoch 97.
# Validation loss improved to 0.2713. Saving model at epoch 97.
# Epoch 101/200 - Train Loss: 0.2438, Validation Loss: 0.2873
# Validation loss improved to 0.2712 at epoch 108.
# Epoch 111/200 - Train Loss: 0.2401, Validation Loss: 0.2846
# Early stopping triggered at epoch 117. Best validation loss was 0.2713 at epoch 97.
# Early stopping triggered. Best validation loss: 0.2712
# Best Train Loss: 0.2356, Best Validation Loss: 0.2712 at Epoch 108
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.01_None.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.01, Scheduler: StepLR ===
# Validation loss improved to 1.3727 at epoch 1.
# Validation loss improved to 1.3727. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4645, Validation Loss: 1.3727
# Validation loss improved to 1.3719 at epoch 4.
# Validation loss improved to 1.3714 at epoch 7.
# Validation loss improved to 1.3714. Saving model at epoch 7.
# Epoch 11/200 - Train Loss: 1.3307, Validation Loss: 1.3728
# Epoch 21/200 - Train Loss: 1.3296, Validation Loss: 1.3727
# Early stopping triggered at epoch 27. Best validation loss was 1.3714 at epoch 7.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3324, Best Validation Loss: 1.3714 at Epoch 7
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.01_StepLR.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.01, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 1.3728 at epoch 1.
# Validation loss improved to 1.3728. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4663, Validation Loss: 1.3728
# Validation loss improved to 1.3715 at epoch 2.
# Validation loss improved to 1.3715. Saving model at epoch 2.
# Epoch 11/200 - Train Loss: 1.3308, Validation Loss: 1.3716
# Validation loss improved to 1.3714 at epoch 12.
# Validation loss improved to 1.3714 at epoch 13.
# Validation loss improved to 1.3714 at epoch 14.
# Validation loss improved to 1.3714 at epoch 16.
# Validation loss improved to 1.3713 at epoch 18.
# Epoch 21/200 - Train Loss: 1.3304, Validation Loss: 1.3748
# Validation loss improved to 1.3705 at epoch 22.
# Early stopping triggered at epoch 22. Best validation loss was 1.3715 at epoch 2.
# Early stopping triggered. Best validation loss: 1.3705
# Best Train Loss: 1.3307, Best Validation Loss: 1.3705 at Epoch 22
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.01_ReduceLROnPlateau.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.1, Scheduler: None ===
# Validation loss improved to 1.3741 at epoch 1.
# Validation loss improved to 1.3741. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4393, Validation Loss: 1.3741
# Validation loss improved to 1.3734 at epoch 3.
# Epoch 11/200 - Train Loss: 1.3724, Validation Loss: 1.4235
# Validation loss improved to 1.3716 at epoch 12.
# Validation loss improved to 1.3716. Saving model at epoch 12.
# Epoch 21/200 - Train Loss: 1.3690, Validation Loss: 1.3785
# Epoch 31/200 - Train Loss: 1.3544, Validation Loss: 1.4012
# Early stopping triggered at epoch 32. Best validation loss was 1.3716 at epoch 12.
# Early stopping triggered. Best validation loss: 1.3716
# Best Train Loss: 1.3625, Best Validation Loss: 1.3716 at Epoch 12
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.1_None.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.1, Scheduler: StepLR ===
# Validation loss improved to 1.3776 at epoch 1.
# Validation loss improved to 1.3776. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4366, Validation Loss: 1.3776
# Validation loss improved to 1.3735 at epoch 2.
# Validation loss improved to 1.3735. Saving model at epoch 2.
# Validation loss improved to 1.3732 at epoch 7.
# Validation loss improved to 1.3728 at epoch 8.
# Validation loss improved to 1.3719 at epoch 11.
# Validation loss improved to 1.3719. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 1.3315, Validation Loss: 1.3719
# Validation loss improved to 1.3718 at epoch 17.
# Validation loss improved to 1.3717 at epoch 20.
# Epoch 21/200 - Train Loss: 1.3306, Validation Loss: 1.3730
# Validation loss improved to 1.3716 at epoch 23.
# Early stopping triggered at epoch 31. Best validation loss was 1.3719 at epoch 11.
# Early stopping triggered. Best validation loss: 1.3716
# Best Train Loss: 1.3303, Best Validation Loss: 1.3716 at Epoch 23
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.1_StepLR.pth
# === Training with Optimizer: SGD_Momentum, LR: 0.1, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 1.3753 at epoch 1.
# Validation loss improved to 1.3753. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4364, Validation Loss: 1.3753
# Validation loss improved to 1.3737 at epoch 7.
# Validation loss improved to 1.3737. Saving model at epoch 7.
# Validation loss improved to 1.3715 at epoch 8.
# Validation loss improved to 1.3715. Saving model at epoch 8.
# Epoch 11/200 - Train Loss: 1.3612, Validation Loss: 1.3927
# Validation loss improved to 1.3714 at epoch 20.
# Epoch 21/200 - Train Loss: 1.3357, Validation Loss: 1.4034
# Early stopping triggered at epoch 28. Best validation loss was 1.3715 at epoch 8.
# Early stopping triggered. Best validation loss: 1.3714
# Best Train Loss: 1.3400, Best Validation Loss: 1.3714 at Epoch 20
#
# Best model saved to models_optimizer/best_model_SGD_Momentum_LR0.1_ReduceLROnPlateau.pth
# === Training with Optimizer: Adam, LR: 0.001, Scheduler: None ===
# Validation loss improved to 0.5455 at epoch 1.
# Validation loss improved to 0.5455. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.9284, Validation Loss: 0.5455
# Validation loss improved to 0.4677 at epoch 2.
# Validation loss improved to 0.4677. Saving model at epoch 2.
# Validation loss improved to 0.4428 at epoch 3.
# Validation loss improved to 0.4428. Saving model at epoch 3.
# Validation loss improved to 0.4376 at epoch 4.
# Validation loss improved to 0.4376. Saving model at epoch 4.
# Validation loss improved to 0.4357 at epoch 5.
# Validation loss improved to 0.4357. Saving model at epoch 5.
# Validation loss improved to 0.4319 at epoch 6.
# Validation loss improved to 0.4319. Saving model at epoch 6.
# Validation loss improved to 0.4287 at epoch 7.
# Validation loss improved to 0.4287. Saving model at epoch 7.
# Validation loss improved to 0.4270 at epoch 8.
# Validation loss improved to 0.4270. Saving model at epoch 8.
# Validation loss improved to 0.4250 at epoch 9.
# Validation loss improved to 0.4250. Saving model at epoch 9.
# Validation loss improved to 0.4187 at epoch 11.
# Validation loss improved to 0.4187. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 0.3901, Validation Loss: 0.4187
# Validation loss improved to 0.4161 at epoch 12.
# Validation loss improved to 0.4161. Saving model at epoch 12.
# Validation loss improved to 0.4108 at epoch 14.
# Validation loss improved to 0.4108. Saving model at epoch 14.
# Validation loss improved to 0.4102 at epoch 17.
# Validation loss improved to 0.4089 at epoch 19.
# Validation loss improved to 0.4089. Saving model at epoch 19.
# Epoch 21/200 - Train Loss: 0.3769, Validation Loss: 0.4155
# Validation loss improved to 0.4055 at epoch 24.
# Validation loss improved to 0.4055. Saving model at epoch 24.
# Validation loss improved to 0.4036 at epoch 25.
# Validation loss improved to 0.4036. Saving model at epoch 25.
# Epoch 31/200 - Train Loss: 0.3685, Validation Loss: 0.4036
# Validation loss improved to 0.3991 at epoch 32.
# Validation loss improved to 0.3991. Saving model at epoch 32.
# Validation loss improved to 0.3966 at epoch 33.
# Validation loss improved to 0.3966. Saving model at epoch 33.
# Validation loss improved to 0.3962 at epoch 36.
# Validation loss improved to 0.3922 at epoch 37.
# Validation loss improved to 0.3922. Saving model at epoch 37.
# Epoch 41/200 - Train Loss: 0.3616, Validation Loss: 0.3935
# Validation loss improved to 0.3922 at epoch 43.
# Validation loss improved to 0.3906 at epoch 44.
# Validation loss improved to 0.3906. Saving model at epoch 44.
# Validation loss improved to 0.3832 at epoch 47.
# Validation loss improved to 0.3832. Saving model at epoch 47.
# Validation loss improved to 0.3803 at epoch 48.
# Validation loss improved to 0.3803. Saving model at epoch 48.
# Validation loss improved to 0.3761 at epoch 49.
# Validation loss improved to 0.3761. Saving model at epoch 49.
# Epoch 51/200 - Train Loss: 0.3481, Validation Loss: 0.3774
# Validation loss improved to 0.3700 at epoch 53.
# Validation loss improved to 0.3700. Saving model at epoch 53.
# Validation loss improved to 0.3688 at epoch 54.
# Validation loss improved to 0.3688. Saving model at epoch 54.
# Validation loss improved to 0.3631 at epoch 56.
# Validation loss improved to 0.3631. Saving model at epoch 56.
# Validation loss improved to 0.3598 at epoch 57.
# Validation loss improved to 0.3598. Saving model at epoch 57.
# Validation loss improved to 0.3574 at epoch 58.
# Validation loss improved to 0.3574. Saving model at epoch 58.
# Validation loss improved to 0.3549 at epoch 60.
# Validation loss improved to 0.3549. Saving model at epoch 60.
# Validation loss improved to 0.3496 at epoch 61.
# Validation loss improved to 0.3496. Saving model at epoch 61.
# Epoch 61/200 - Train Loss: 0.3217, Validation Loss: 0.3496
# Validation loss improved to 0.3489 at epoch 62.
# Validation loss improved to 0.3454 at epoch 63.
# Validation loss improved to 0.3454. Saving model at epoch 63.
# Validation loss improved to 0.3448 at epoch 65.
# Validation loss improved to 0.3431 at epoch 66.
# Validation loss improved to 0.3431. Saving model at epoch 66.
# Validation loss improved to 0.3373 at epoch 67.
# Validation loss improved to 0.3373. Saving model at epoch 67.
# Validation loss improved to 0.3348 at epoch 68.
# Validation loss improved to 0.3348. Saving model at epoch 68.
# Validation loss improved to 0.3270 at epoch 70.
# Validation loss improved to 0.3270. Saving model at epoch 70.
# Validation loss improved to 0.3215 at epoch 71.
# Validation loss improved to 0.3215. Saving model at epoch 71.
# Epoch 71/200 - Train Loss: 0.2942, Validation Loss: 0.3215
# Validation loss improved to 0.3168 at epoch 73.
# Validation loss improved to 0.3168. Saving model at epoch 73.
# Validation loss improved to 0.3164 at epoch 74.
# Validation loss improved to 0.3142 at epoch 77.
# Validation loss improved to 0.3142. Saving model at epoch 77.
# Validation loss improved to 0.3128 at epoch 78.
# Validation loss improved to 0.3128. Saving model at epoch 78.
# Epoch 81/200 - Train Loss: 0.2784, Validation Loss: 0.3232
# Validation loss improved to 0.3088 at epoch 82.
# Validation loss improved to 0.3088. Saving model at epoch 82.
# Validation loss improved to 0.3060 at epoch 83.
# Validation loss improved to 0.3060. Saving model at epoch 83.
# Validation loss improved to 0.3022 at epoch 87.
# Validation loss improved to 0.3022. Saving model at epoch 87.
# Validation loss improved to 0.2999 at epoch 89.
# Validation loss improved to 0.2999. Saving model at epoch 89.
# Validation loss improved to 0.2965 at epoch 90.
# Validation loss improved to 0.2965. Saving model at epoch 90.
# Validation loss improved to 0.2922 at epoch 91.
# Validation loss improved to 0.2922. Saving model at epoch 91.
# Epoch 91/200 - Train Loss: 0.2646, Validation Loss: 0.2922
# Validation loss improved to 0.2896 at epoch 98.
# Validation loss improved to 0.2896. Saving model at epoch 98.
# Epoch 101/200 - Train Loss: 0.2604, Validation Loss: 0.2920
# Validation loss improved to 0.2873 at epoch 102.
# Validation loss improved to 0.2873. Saving model at epoch 102.
# Validation loss improved to 0.2868 at epoch 111.
# Epoch 111/200 - Train Loss: 0.2562, Validation Loss: 0.2868
# Validation loss improved to 0.2868 at epoch 118.
# Validation loss improved to 0.2832 at epoch 121.
# Validation loss improved to 0.2832. Saving model at epoch 121.
# Epoch 121/200 - Train Loss: 0.2516, Validation Loss: 0.2832
# Validation loss improved to 0.2831 at epoch 123.
# Validation loss improved to 0.2830 at epoch 127.
# Epoch 131/200 - Train Loss: 0.2460, Validation Loss: 0.2924
# Early stopping triggered at epoch 141. Best validation loss was 0.2832 at epoch 121.
# Early stopping triggered. Best validation loss: 0.2830
# Best Train Loss: 0.2492, Best Validation Loss: 0.2830 at Epoch 127
#
# Best model saved to models_optimizer/best_model_Adam_LR0.001_None.pth
# === Training with Optimizer: Adam, LR: 0.001, Scheduler: StepLR ===
# Validation loss improved to 0.5170 at epoch 1.
# Validation loss improved to 0.5170. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.6663, Validation Loss: 0.5170
# Validation loss improved to 0.4639 at epoch 2.
# Validation loss improved to 0.4639. Saving model at epoch 2.
# Validation loss improved to 0.4473 at epoch 3.
# Validation loss improved to 0.4473. Saving model at epoch 3.
# Validation loss improved to 0.4376 at epoch 4.
# Validation loss improved to 0.4376. Saving model at epoch 4.
# Validation loss improved to 0.4296 at epoch 5.
# Validation loss improved to 0.4296. Saving model at epoch 5.
# Validation loss improved to 0.4254 at epoch 6.
# Validation loss improved to 0.4254. Saving model at epoch 6.
# Validation loss improved to 0.4202 at epoch 10.
# Validation loss improved to 0.4202. Saving model at epoch 10.
# Validation loss improved to 0.4162 at epoch 11.
# Validation loss improved to 0.4162. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 0.3828, Validation Loss: 0.4162
# Validation loss improved to 0.4156 at epoch 12.
# Validation loss improved to 0.4146 at epoch 13.
# Validation loss improved to 0.4146. Saving model at epoch 13.
# Validation loss improved to 0.4136 at epoch 15.
# Validation loss improved to 0.4136. Saving model at epoch 15.
# Validation loss improved to 0.4127 at epoch 18.
# Epoch 21/200 - Train Loss: 0.3784, Validation Loss: 0.4128
# Validation loss improved to 0.4126 at epoch 23.
# Validation loss improved to 0.4126 at epoch 24.
# Validation loss improved to 0.4126 at epoch 27.
# Validation loss improved to 0.4126. Saving model at epoch 27.
# Validation loss improved to 0.4126 at epoch 30.
# Validation loss improved to 0.4126 at epoch 31.
# Epoch 31/200 - Train Loss: 0.3778, Validation Loss: 0.4126
# Validation loss improved to 0.4125 at epoch 32.
# Validation loss improved to 0.4125 at epoch 33.
# Validation loss improved to 0.4125 at epoch 34.
# Validation loss improved to 0.4125 at epoch 35.
# Validation loss improved to 0.4125 at epoch 36.
# Validation loss improved to 0.4125 at epoch 38.
# Validation loss improved to 0.4125 at epoch 40.
# Validation loss improved to 0.4125 at epoch 41.
# Epoch 41/200 - Train Loss: 0.3780, Validation Loss: 0.4125
# Validation loss improved to 0.4125 at epoch 42.
# Validation loss improved to 0.4125 at epoch 43.
# Validation loss improved to 0.4125 at epoch 44.
# Validation loss improved to 0.4125 at epoch 46.
# Validation loss improved to 0.4125 at epoch 47.
# Early stopping triggered at epoch 47. Best validation loss was 0.4126 at epoch 27.
# Early stopping triggered. Best validation loss: 0.4125
# Best Train Loss: 0.3778, Best Validation Loss: 0.4125 at Epoch 47
#
# Best model saved to models_optimizer/best_model_Adam_LR0.001_StepLR.pth
# === Training with Optimizer: Adam, LR: 0.001, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 0.5377 at epoch 1.
# Validation loss improved to 0.5377. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.7929, Validation Loss: 0.5377
# Validation loss improved to 0.4562 at epoch 2.
# Validation loss improved to 0.4562. Saving model at epoch 2.
# Validation loss improved to 0.4435 at epoch 3.
# Validation loss improved to 0.4435. Saving model at epoch 3.
# Validation loss improved to 0.4356 at epoch 4.
# Validation loss improved to 0.4356. Saving model at epoch 4.
# Validation loss improved to 0.4295 at epoch 5.
# Validation loss improved to 0.4295. Saving model at epoch 5.
# Validation loss improved to 0.4288 at epoch 6.
# Validation loss improved to 0.4237 at epoch 9.
# Validation loss improved to 0.4237. Saving model at epoch 9.
# Validation loss improved to 0.4119 at epoch 11.
# Validation loss improved to 0.4119. Saving model at epoch 11.
# Epoch 11/200 - Train Loss: 0.3875, Validation Loss: 0.4119
# Validation loss improved to 0.4112 at epoch 13.
# Validation loss improved to 0.4075 at epoch 14.
# Validation loss improved to 0.4075. Saving model at epoch 14.
# Epoch 21/200 - Train Loss: 0.3722, Validation Loss: 0.4077
# Validation loss improved to 0.4034 at epoch 22.
# Validation loss improved to 0.4034. Saving model at epoch 22.
# Validation loss improved to 0.4028 at epoch 25.
# Validation loss improved to 0.4024 at epoch 30.
# Validation loss improved to 0.4024. Saving model at epoch 30.
# Validation loss improved to 0.4011 at epoch 31.
# Validation loss improved to 0.4011. Saving model at epoch 31.
# Epoch 31/200 - Train Loss: 0.3684, Validation Loss: 0.4011
# Validation loss improved to 0.3996 at epoch 35.
# Validation loss improved to 0.3996. Saving model at epoch 35.
# Validation loss improved to 0.3989 at epoch 36.
# Validation loss improved to 0.3972 at epoch 37.
# Validation loss improved to 0.3972. Saving model at epoch 37.
# Validation loss improved to 0.3936 at epoch 39.
# Validation loss improved to 0.3936. Saving model at epoch 39.
# Validation loss improved to 0.3887 at epoch 41.
# Validation loss improved to 0.3887. Saving model at epoch 41.
# Epoch 41/200 - Train Loss: 0.3561, Validation Loss: 0.3887
# Validation loss improved to 0.3862 at epoch 43.
# Validation loss improved to 0.3862. Saving model at epoch 43.
# Validation loss improved to 0.3825 at epoch 46.
# Validation loss improved to 0.3825. Saving model at epoch 46.
# Validation loss improved to 0.3785 at epoch 48.
# Validation loss improved to 0.3785. Saving model at epoch 48.
# Validation loss improved to 0.3765 at epoch 50.
# Validation loss improved to 0.3765. Saving model at epoch 50.
# Validation loss improved to 0.3763 at epoch 51.
# Epoch 51/200 - Train Loss: 0.3434, Validation Loss: 0.3763
# Validation loss improved to 0.3761 at epoch 52.
# Validation loss improved to 0.3727 at epoch 54.
# Validation loss improved to 0.3727. Saving model at epoch 54.
# Validation loss improved to 0.3683 at epoch 56.
# Validation loss improved to 0.3683. Saving model at epoch 56.
# Validation loss improved to 0.3658 at epoch 59.
# Validation loss improved to 0.3658. Saving model at epoch 59.
# Validation loss improved to 0.3655 at epoch 60.
# Validation loss improved to 0.3614 at epoch 61.
# Validation loss improved to 0.3614. Saving model at epoch 61.
# Epoch 61/200 - Train Loss: 0.3309, Validation Loss: 0.3614
# Validation loss improved to 0.3606 at epoch 62.
# Validation loss improved to 0.3554 at epoch 64.
# Validation loss improved to 0.3554. Saving model at epoch 64.
# Validation loss improved to 0.3535 at epoch 65.
# Validation loss improved to 0.3535. Saving model at epoch 65.
# Validation loss improved to 0.3533 at epoch 68.
# Validation loss improved to 0.3494 at epoch 69.
# Validation loss improved to 0.3494. Saving model at epoch 69.
# Epoch 71/200 - Train Loss: 0.3183, Validation Loss: 0.3507
# Validation loss improved to 0.3468 at epoch 72.
# Validation loss improved to 0.3468. Saving model at epoch 72.
# Validation loss improved to 0.3460 at epoch 73.
# Validation loss improved to 0.3451 at epoch 74.
# Validation loss improved to 0.3451. Saving model at epoch 74.
# Validation loss improved to 0.3411 at epoch 75.
# Validation loss improved to 0.3411. Saving model at epoch 75.
# Validation loss improved to 0.3382 at epoch 76.
# Validation loss improved to 0.3382. Saving model at epoch 76.
# Validation loss improved to 0.3374 at epoch 78.
# Validation loss improved to 0.3325 at epoch 79.
# Validation loss improved to 0.3325. Saving model at epoch 79.
# ...
# Validation loss improved to 0.3416 at epoch 12.
# Validation loss improved to 0.3416. Saving model at epoch 12.
# Validation loss improved to 0.3385 at epoch 13.
# Validation loss improved to 0.3385. Saving model at epoch 13.
# Validation loss improved to 0.3372 at epoch 14.
# Validation loss improved to 0.3372. Saving model at epoch 14.
# Validation loss improved to 0.3346 at epoch 15.
# Validation loss improved to 0.3346. Saving model at epoch 15.
# Validation loss improved to 0.3316 at epoch 16.
# Validation loss improved to 0.3316. Saving model at epoch 16.
# Validation loss improved to 0.3293 at epoch 17.
# Validation loss improved to 0.3293. Saving model at epoch 17.
# Validation loss improved to 0.3253 at epoch 19.
# Validation loss improved to 0.3253. Saving model at epoch 19.
# Validation loss improved to 0.3224 at epoch 20.
# Validation loss improved to 0.3224. Saving model at epoch 20.
# Validation loss improved to 0.3212 at epoch 21.
# Validation loss improved to 0.3212. Saving model at epoch 21.
# Epoch 21/200 - Train Loss: 0.2881, Validation Loss: 0.3212
# Validation loss improved to 0.3210 at epoch 22.
# Validation loss improved to 0.3206 at epoch 24.
# Validation loss improved to 0.3204 at epoch 25.
# Validation loss improved to 0.3201 at epoch 27.
# Validation loss improved to 0.3201. Saving model at epoch 27.
# Validation loss improved to 0.3198 at epoch 29.
# Epoch 31/200 - Train Loss: 0.2848, Validation Loss: 0.3199
# Epoch 41/200 - Train Loss: 0.2841, Validation Loss: 0.3199
# Early stopping triggered at epoch 47. Best validation loss was 0.3201 at epoch 27.
# Early stopping triggered. Best validation loss: 0.3198
# Best Train Loss: 0.2852, Best Validation Loss: 0.3198 at Epoch 29
#
# Best model saved to models_optimizer/best_model_Adam_LR0.01_StepLR.pth
# === Training with Optimizer: Adam, LR: 0.01, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 0.4736 at epoch 1.
# Validation loss improved to 0.4736. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 0.7600, Validation Loss: 0.4736
# Validation loss improved to 0.4623 at epoch 2.
# Validation loss improved to 0.4623. Saving model at epoch 2.
# Validation loss improved to 0.4527 at epoch 3.
# Validation loss improved to 0.4527. Saving model at epoch 3.
# Validation loss improved to 0.4231 at epoch 4.
# Validation loss improved to 0.4231. Saving model at epoch 4.
# Validation loss improved to 0.4037 at epoch 5.
# Validation loss improved to 0.4037. Saving model at epoch 5.
# Validation loss improved to 0.3927 at epoch 8.
# Validation loss improved to 0.3927. Saving model at epoch 8.
# Epoch 11/200 - Train Loss: 0.3754, Validation Loss: 0.3937
# Validation loss improved to 0.3778 at epoch 13.
# Validation loss improved to 0.3778. Saving model at epoch 13.
# Validation loss improved to 0.3429 at epoch 14.
# Validation loss improved to 0.3429. Saving model at epoch 14.
# Validation loss improved to 0.3309 at epoch 17.
# Validation loss improved to 0.3309. Saving model at epoch 17.
# Validation loss improved to 0.3238 at epoch 20.
# Validation loss improved to 0.3238. Saving model at epoch 20.
# Epoch 21/200 - Train Loss: 0.3041, Validation Loss: 0.3390
# Validation loss improved to 0.3130 at epoch 24.
# Validation loss improved to 0.3130. Saving model at epoch 24.
# Validation loss improved to 0.3056 at epoch 27.
# Validation loss improved to 0.3056. Saving model at epoch 27.
# Epoch 31/200 - Train Loss: 0.2891, Validation Loss: 0.3130
# Validation loss improved to 0.3051 at epoch 34.
# Validation loss improved to 0.3018 at epoch 35.
# Validation loss improved to 0.3018. Saving model at epoch 35.
# Validation loss improved to 0.2962 at epoch 36.
# Validation loss improved to 0.2962. Saving model at epoch 36.
# Validation loss improved to 0.2948 at epoch 37.
# Validation loss improved to 0.2948. Saving model at epoch 37.
# Validation loss improved to 0.2905 at epoch 41.
# Validation loss improved to 0.2905. Saving model at epoch 41.
# Epoch 41/200 - Train Loss: 0.2584, Validation Loss: 0.2905
# Validation loss improved to 0.2891 at epoch 44.
# Validation loss improved to 0.2891. Saving model at epoch 44.
# Validation loss improved to 0.2878 at epoch 48.
# Validation loss improved to 0.2878. Saving model at epoch 48.
# Validation loss improved to 0.2863 at epoch 50.
# Validation loss improved to 0.2863. Saving model at epoch 50.
# Epoch 51/200 - Train Loss: 0.2501, Validation Loss: 0.2988
# Validation loss improved to 0.2810 at epoch 57.
# Validation loss improved to 0.2810. Saving model at epoch 57.
# Validation loss improved to 0.2766 at epoch 59.
# Validation loss improved to 0.2766. Saving model at epoch 59.
# Epoch 61/200 - Train Loss: 0.2303, Validation Loss: 0.2786
# Validation loss improved to 0.2753 at epoch 67.
# Validation loss improved to 0.2753. Saving model at epoch 67.
# Validation loss improved to 0.2746 at epoch 69.
# Epoch 71/200 - Train Loss: 0.2187, Validation Loss: 0.2792
# Validation loss improved to 0.2745 at epoch 81.
# Epoch 81/200 - Train Loss: 0.2118, Validation Loss: 0.2745
# Validation loss improved to 0.2744 at epoch 82.
# Early stopping triggered at epoch 87. Best validation loss was 0.2753 at epoch 67.
# Early stopping triggered. Best validation loss: 0.2744
# Best Train Loss: 0.2120, Best Validation Loss: 0.2744 at Epoch 82
#
# Best model saved to models_optimizer/best_model_Adam_LR0.01_ReduceLROnPlateau.pth
# === Training with Optimizer: Adam, LR: 0.1, Scheduler: None ===
# Validation loss improved to 0.5702 at epoch 1.
# Validation loss improved to 0.5702. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 3.2990, Validation Loss: 0.5702
# Validation loss improved to 0.4791 at epoch 3.
# Validation loss improved to 0.4791. Saving model at epoch 3.
# Validation loss improved to 0.4559 at epoch 4.
# Validation loss improved to 0.4559. Saving model at epoch 4.
# Validation loss improved to 0.3974 at epoch 6.
# Validation loss improved to 0.3974. Saving model at epoch 6.
# Epoch 11/200 - Train Loss: 0.4501, Validation Loss: 0.4081
# Validation loss improved to 0.3806 at epoch 14.
# Validation loss improved to 0.3806. Saving model at epoch 14.
# Epoch 21/200 - Train Loss: 0.3911, Validation Loss: 0.4318
# Validation loss improved to 0.3733 at epoch 28.
# Validation loss improved to 0.3733. Saving model at epoch 28.
# Epoch 31/200 - Train Loss: 0.4075, Validation Loss: 0.3963
# Epoch 41/200 - Train Loss: 0.4018, Validation Loss: 0.4617
# Early stopping triggered at epoch 48. Best validation loss was 0.3733 at epoch 28.
# Early stopping triggered. Best validation loss: 0.3733
# Best Train Loss: 0.3833, Best Validation Loss: 0.3733 at Epoch 28
#
# Best model saved to models_optimizer/best_model_Adam_LR0.1_None.pth
# === Training with Optimizer: Adam, LR: 0.1, Scheduler: StepLR ===
# Validation loss improved to 0.4749 at epoch 1.
# Validation loss improved to 0.4749. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.6497, Validation Loss: 0.4749
# Validation loss improved to 0.3963 at epoch 4.
# Validation loss improved to 0.3963. Saving model at epoch 4.
# Epoch 11/200 - Train Loss: 0.3905, Validation Loss: 0.4006
# Validation loss improved to 0.3918 at epoch 13.
# Validation loss improved to 0.3918. Saving model at epoch 13.
# Validation loss improved to 0.3818 at epoch 14.
# Validation loss improved to 0.3818. Saving model at epoch 14.
# Validation loss improved to 0.3814 at epoch 15.
# Validation loss improved to 0.3709 at epoch 16.
# Validation loss improved to 0.3709. Saving model at epoch 16.
# Validation loss improved to 0.3694 at epoch 17.
# Validation loss improved to 0.3694. Saving model at epoch 17.
# Validation loss improved to 0.3632 at epoch 19.
# Validation loss improved to 0.3632. Saving model at epoch 19.
# Validation loss improved to 0.3599 at epoch 21.
# Validation loss improved to 0.3599. Saving model at epoch 21.
# Epoch 21/200 - Train Loss: 0.3256, Validation Loss: 0.3599
# Validation loss improved to 0.3594 at epoch 22.
# Validation loss improved to 0.3582 at epoch 23.
# Validation loss improved to 0.3582. Saving model at epoch 23.
# Validation loss improved to 0.3576 at epoch 24.
# Validation loss improved to 0.3567 at epoch 25.
# Validation loss improved to 0.3567. Saving model at epoch 25.
# Validation loss improved to 0.3564 at epoch 27.
# Validation loss improved to 0.3563 at epoch 28.
# Validation loss improved to 0.3561 at epoch 29.
# Validation loss improved to 0.3560 at epoch 31.
# Epoch 31/200 - Train Loss: 0.3216, Validation Loss: 0.3560
# Validation loss improved to 0.3559 at epoch 32.
# Validation loss improved to 0.3559 at epoch 33.
# Validation loss improved to 0.3559 at epoch 34.
# Validation loss improved to 0.3558 at epoch 35.
# Validation loss improved to 0.3558 at epoch 38.
# Validation loss improved to 0.3558 at epoch 39.
# Epoch 41/200 - Train Loss: 0.3209, Validation Loss: 0.3558
# Validation loss improved to 0.3558 at epoch 44.
# Validation loss improved to 0.3558 at epoch 45.
# Early stopping triggered at epoch 45. Best validation loss was 0.3567 at epoch 25.
# Early stopping triggered. Best validation loss: 0.3558
# Best Train Loss: 0.3209, Best Validation Loss: 0.3558 at Epoch 45
#
# Best model saved to models_optimizer/best_model_Adam_LR0.1_StepLR.pth
# === Training with Optimizer: Adam, LR: 0.1, Scheduler: ReduceLROnPlateau ===
# Validation loss improved to 0.4188 at epoch 1.
# Validation loss improved to 0.4188. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 0.8084, Validation Loss: 0.4188
# Validation loss improved to 0.3849 at epoch 7.
# Validation loss improved to 0.3849. Saving model at epoch 7.
# Validation loss improved to 0.3773 at epoch 8.
# Validation loss improved to 0.3773. Saving model at epoch 8.
# Epoch 11/200 - Train Loss: 0.3801, Validation Loss: 0.3853
# Validation loss improved to 0.3536 at epoch 16.
# Validation loss improved to 0.3536. Saving model at epoch 16.
# Validation loss improved to 0.3464 at epoch 21.
# Validation loss improved to 0.3464. Saving model at epoch 21.
# Epoch 21/200 - Train Loss: 0.3414, Validation Loss: 0.3464
# Validation loss improved to 0.3394 at epoch 25.
# Validation loss improved to 0.3394. Saving model at epoch 25.
# Epoch 31/200 - Train Loss: 0.3266, Validation Loss: 0.3532
# Validation loss improved to 0.3391 at epoch 34.
# Validation loss improved to 0.3316 at epoch 36.
# Validation loss improved to 0.3316. Saving model at epoch 36.
# Validation loss improved to 0.3313 at epoch 40.
# Validation loss improved to 0.3280 at epoch 41.
# Validation loss improved to 0.3280. Saving model at epoch 41.
# Epoch 41/200 - Train Loss: 0.3099, Validation Loss: 0.3280
# Validation loss improved to 0.3240 at epoch 42.
# Validation loss improved to 0.3240. Saving model at epoch 42.
# Validation loss improved to 0.3233 at epoch 49.
# Validation loss improved to 0.3202 at epoch 50.
# Validation loss improved to 0.3202. Saving model at epoch 50.
# Epoch 51/200 - Train Loss: 0.2950, Validation Loss: 0.3236
# Validation loss improved to 0.3161 at epoch 57.
# Validation loss improved to 0.3161. Saving model at epoch 57.
# Validation loss improved to 0.3157 at epoch 61.
# Epoch 61/200 - Train Loss: 0.2866, Validation Loss: 0.3157
# Epoch 71/200 - Train Loss: 0.2832, Validation Loss: 0.3175
# Validation loss improved to 0.3144 at epoch 75.
# Validation loss improved to 0.3144. Saving model at epoch 75.
# Epoch 81/200 - Train Loss: 0.2809, Validation Loss: 0.3163
# Epoch 91/200 - Train Loss: 0.2792, Validation Loss: 0.3150
# Early stopping triggered at epoch 95. Best validation loss was 0.3144 at epoch 75.
# Early stopping triggered. Best validation loss: 0.3144
# Best Train Loss: 0.2804, Best Validation Loss: 0.3144 at Epoch 75
#
# Best model saved to models_optimizer/best_model_Adam_LR0.1_ReduceLROnPlateau.pth
# === Optimizer and Scheduler Comparison Results ===
#        Optimizer  Learning Rate          Scheduler  Best Train Loss  \
# 0            SGD          0.001               None         1.330372
# 1            SGD          0.001             StepLR         1.330080
# 2            SGD          0.001  ReduceLROnPlateau         1.331091
# 3            SGD          0.010               None         1.329693
# 4            SGD          0.010             StepLR         1.330726
# 5            SGD          0.010  ReduceLROnPlateau         1.329199
# 6            SGD          0.100               None         0.220088
# 7            SGD          0.100             StepLR         0.353499
# 8            SGD          0.100  ReduceLROnPlateau         0.225520
# 9   SGD_Momentum          0.001               None         1.329299
# 10  SGD_Momentum          0.001             StepLR         1.330048
# 11  SGD_Momentum          0.001  ReduceLROnPlateau         1.329733
# 12  SGD_Momentum          0.010               None         0.235574
# 13  SGD_Momentum          0.010             StepLR         1.332386
# 14  SGD_Momentum          0.010  ReduceLROnPlateau         1.330657
# 15  SGD_Momentum          0.100               None         1.362499
# 16  SGD_Momentum          0.100             StepLR         1.330277
# 17  SGD_Momentum          0.100  ReduceLROnPlateau         1.339958
# 18          Adam          0.001               None         0.249227
# 19          Adam          0.001             StepLR         0.377784
# 20          Adam          0.001  ReduceLROnPlateau         0.259636
# 21          Adam          0.010               None         0.256502
# 22          Adam          0.010             StepLR         0.285249
# 23          Adam          0.010  ReduceLROnPlateau         0.211952
# 24          Adam          0.100               None         0.383333
# 25          Adam          0.100             StepLR         0.320889
# 26          Adam          0.100  ReduceLROnPlateau         0.280388
#
#     Best Val Loss  Best Epoch  \
# 0        1.372258          19
# 1        1.372781          35
# 2        1.372247          21
# 3        1.371368          20
# 4        1.371402           8
# 5        1.371382          14
# 6        0.272316         167
# 7        0.383120          59
# 8        0.273358         119
# 9        1.371404          14
# 10       1.371566           2
# 11       1.371427          15
# 12       0.271220         108
# 13       1.371384           7
# 14       1.370508          22
# 15       1.371562          12
# 16       1.371583          23
# 17       1.371420          20
# 18       0.283020         127
# 19       0.412496          47
# 20       0.301456         175
# 21       0.287331          57
# 22       0.319814          29
# 23       0.274383          82
# 24       0.373302          28
# 25       0.355785          45
# 26       0.314357          75
#
#                                            Model Path
# 0    models_optimizer/best_model_SGD_LR0.001_None.pth
# 1   models_optimizer/best_model_SGD_LR0.001_StepLR...
# 2   models_optimizer/best_model_SGD_LR0.001_Reduce...
# 3     models_optimizer/best_model_SGD_LR0.01_None.pth
# 4   models_optimizer/best_model_SGD_LR0.01_StepLR.pth
# 5   models_optimizer/best_model_SGD_LR0.01_ReduceL...
# 6      models_optimizer/best_model_SGD_LR0.1_None.pth
# 7    models_optimizer/best_model_SGD_LR0.1_StepLR.pth
# 8   models_optimizer/best_model_SGD_LR0.1_ReduceLR...
# 9   models_optimizer/best_model_SGD_Momentum_LR0.0...
# 10  models_optimizer/best_model_SGD_Momentum_LR0.0...
# 11  models_optimizer/best_model_SGD_Momentum_LR0.0...
# 12  models_optimizer/best_model_SGD_Momentum_LR0.0...
# 13  models_optimizer/best_model_SGD_Momentum_LR0.0...
# 14  models_optimizer/best_model_SGD_Momentum_LR0.0...
# 15  models_optimizer/best_model_SGD_Momentum_LR0.1...
# 16  models_optimizer/best_model_SGD_Momentum_LR0.1...
# 17  models_optimizer/best_model_SGD_Momentum_LR0.1...
# 18  models_optimizer/best_model_Adam_LR0.001_None.pth
# 19  models_optimizer/best_model_Adam_LR0.001_StepL...
# 20  models_optimizer/best_model_Adam_LR0.001_Reduc...
# 21   models_optimizer/best_model_Adam_LR0.01_None.pth
# 22  models_optimizer/best_model_Adam_LR0.01_StepLR...
# 23  models_optimizer/best_model_Adam_LR0.01_Reduce...
# 24    models_optimizer/best_model_Adam_LR0.1_None.pth
# 25  models_optimizer/best_model_Adam_LR0.1_StepLR.pth
# 26  models_optimizer/best_model_Adam_LR0.1_ReduceL...

# %% [markdown]
# ## Task d)

# %%
set_seed(seed)
generator = torch.Generator()
generator.manual_seed(0)

# Retraining the best model to obtain the validation and train losses for the plot
train_dataset = TensorDataset(X_new_train, y_new_train)
train_iter = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

val_dataset = TensorDataset(X_val, y_val)
val_iter = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

batch_size = 50
num_epochs = 200
architecture = [8, 64, 32, 16, 1]

model_save_dir = "models_optimizer"
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)

criterion = nn.MSELoss()
max_grad_norm = 5.0

optimizer_config = {"name": "SGD_Momentum", "optimizer": SGD, "params": {"lr": 1e-2, "momentum": 0.9}}
scheduler_config = {"name": "None", "scheduler": None, "params": {}}

results = []
train_losses = []
val_losses = []
best_train_loss = []
best_val_loss = []
best_epoch = []
best_model_state = []
        
model = create_model(architecture)
early_stopping = EarlyStopping(patience=40, delta=0.001)

train_losses, val_losses, best_train_loss, best_val_loss, best_epoch, best_model_state = train_and_validate(
    model,
    train_iter,
    val_iter,
    num_epochs,
    optimizer_cls=optimizer_config["optimizer"],
    optimizer_params=optimizer_config["params"],
    scheduler_cls=scheduler_config["scheduler"],
    scheduler_params=scheduler_config["params"],
    early_stopping=early_stopping
)

# Plot Training and Validation Losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Training and Validation Losses")
plt.legend()
plt.grid()
plt.show()
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
# Validation loss improved to 1.3818 at epoch 1.
# Validation loss improved to 1.3818. Saving model at epoch 1.
# Epoch 1/200 - Train Loss: 1.4634, Validation Loss: 1.3818
# Validation loss improved to 1.3715 at epoch 3.
# Validation loss improved to 1.3715. Saving model at epoch 3.
# Validation loss improved to 1.3715 at epoch 4.
# Epoch 11/200 - Train Loss: 1.3332, Validation Loss: 1.3717
# Validation loss improved to 1.3715 at epoch 15.
# Validation loss improved to 1.3715 at epoch 18.
# Epoch 21/200 - Train Loss: 1.3316, Validation Loss: 1.3741
# Validation loss improved to 1.3714 at epoch 27.
# Epoch 31/200 - Train Loss: 1.3334, Validation Loss: 1.3715
# Validation loss improved to 0.7212 at epoch 34.
# Validation loss improved to 0.7212. Saving model at epoch 34.
# Validation loss improved to 0.5116 at epoch 35.
# Validation loss improved to 0.5116. Saving model at epoch 35.
# Validation loss improved to 0.4267 at epoch 36.
# Validation loss improved to 0.4267. Saving model at epoch 36.
# Validation loss improved to 0.4025 at epoch 38.
# Validation loss improved to 0.4025. Saving model at epoch 38.
# Validation loss improved to 0.3840 at epoch 40.
# Validation loss improved to 0.3840. Saving model at epoch 40.
# Validation loss improved to 0.3613 at epoch 41.
# Validation loss improved to 0.3613. Saving model at epoch 41.
# Epoch 41/200 - Train Loss: 0.3572, Validation Loss: 0.3613
# Validation loss improved to 0.3519 at epoch 46.
# Validation loss improved to 0.3519. Saving model at epoch 46.
# Validation loss improved to 0.3416 at epoch 48.
# Validation loss improved to 0.3416. Saving model at epoch 48.
# Validation loss improved to 0.3328 at epoch 49.
# Validation loss improved to 0.3328. Saving model at epoch 49.
# Epoch 51/200 - Train Loss: 0.3118, Validation Loss: 0.4220
# Validation loss improved to 0.3211 at epoch 52.
# Validation loss improved to 0.3211. Saving model at epoch 52.
# Validation loss improved to 0.3127 at epoch 54.
# Validation loss improved to 0.3127. Saving model at epoch 54.
# Validation loss improved to 0.3121 at epoch 56.
# Validation loss improved to 0.3118 at epoch 59.
# Epoch 61/200 - Train Loss: 0.2894, Validation Loss: 0.3160
# Validation loss improved to 0.3005 at epoch 64.
# Validation loss improved to 0.3005. Saving model at epoch 64.
# Epoch 71/200 - Train Loss: 0.2754, Validation Loss: 0.3390
# Validation loss improved to 0.3003 at epoch 75.
# Validation loss improved to 0.2983 at epoch 77.
# Validation loss improved to 0.2983. Saving model at epoch 77.
# Validation loss improved to 0.2931 at epoch 78.
# Validation loss improved to 0.2931. Saving model at epoch 78.
# Validation loss improved to 0.2897 at epoch 80.
# Validation loss improved to 0.2897. Saving model at epoch 80.
# Epoch 81/200 - Train Loss: 0.2664, Validation Loss: 0.2988
# Validation loss improved to 0.2878 at epoch 87.
# Validation loss improved to 0.2878. Saving model at epoch 87.
# Validation loss improved to 0.2819 at epoch 88.
# Validation loss improved to 0.2819. Saving model at epoch 88.
# Epoch 91/200 - Train Loss: 0.2545, Validation Loss: 0.2986
# Validation loss improved to 0.2801 at epoch 99.
# Validation loss improved to 0.2801. Saving model at epoch 99.
# Epoch 101/200 - Train Loss: 0.2526, Validation Loss: 0.2940
# Epoch 111/200 - Train Loss: 0.2483, Validation Loss: 0.2894
# Epoch 121/200 - Train Loss: 0.2399, Validation Loss: 0.2907
# Validation loss improved to 0.2785 at epoch 125.
# Validation loss improved to 0.2785. Saving model at epoch 125.
# Epoch 131/200 - Train Loss: 0.2342, Validation Loss: 0.2858
# Validation loss improved to 0.2769 at epoch 133.
# Validation loss improved to 0.2769. Saving model at epoch 133.
# Validation loss improved to 0.2763 at epoch 136.
# Epoch 141/200 - Train Loss: 0.2294, Validation Loss: 0.2882
# Epoch 151/200 - Train Loss: 0.2262, Validation Loss: 0.3022
# Validation loss improved to 0.2746 at epoch 159.
# Validation loss improved to 0.2746. Saving model at epoch 159.
# Epoch 161/200 - Train Loss: 0.2258, Validation Loss: 0.2957
# Epoch 171/200 - Train Loss: 0.2246, Validation Loss: 0.2842
# Epoch 181/200 - Train Loss: 0.2167, Validation Loss: 0.2865
# Epoch 191/200 - Train Loss: 0.2127, Validation Loss: 0.2869
# Early stopping triggered at epoch 199. Best validation loss was 0.2746 at epoch 159.
# Early stopping triggered. Best validation loss: 0.2746

# %%
set_seed(seed)
generator = torch.Generator()
generator.manual_seed(0)

# Combine training and validation data
X_combined = torch.cat([X_new_train, X_val], dim=0)
y_combined = torch.cat([y_new_train, y_val], dim=0)

combined_dataset = TensorDataset(X_combined, y_combined)
combined_iter = DataLoader(combined_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
    worker_init_fn=seed_worker,
    generator=generator)

# Initialize and train the final model
batch_size = 50
num_epochs = 200
architecture = [8, 64, 32, 16, 1]
max_grad_norm = 5.0

final_model = create_model(architecture)
optimizer_config = {"name": "SGD_Momentum", "optimizer": SGD, "params": {"lr": 1e-2, "momentum": 0.9}}
final_optimizer = optimizer_config["optimizer"](final_model.parameters(), **optimizer_config["params"])
final_criterion = nn.MSELoss()

schedulers = []
scheduler = None

final_train_losses = []
print("Final model training started.")
for epoch in range(num_epochs):
    final_model.train()
    epoch_loss = 0
    for X_batch, y_batch in combined_iter:
        final_optimizer.zero_grad()
        y_pred = final_model(X_batch)
        loss = final_criterion(y_pred, y_batch)
        loss.backward()
        nn.utils.clip_grad_norm_(final_model.parameters(), max_grad_norm)
        final_optimizer.step()
        epoch_loss += loss.item()

    final_train_losses.append(epoch_loss / len(combined_iter))

    if scheduler:
        scheduler.step(epoch_loss / len(combined_iter))
    
    if epoch % 10 == 0 or epoch == num_epochs - 1:
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss / len(combined_iter):.4f}")

# Save the final model
torch.save(final_model.state_dict(), f"{model_save_dir}/final_model.pth")
print("Final model training completed.")

# Test the model
final_model.eval()
y_test_pred = None
test_loss = None
with torch.no_grad():
    y_test_pred = final_model(X_test)
    test_loss = final_criterion(y_test_pred, y_test).item()

print(f"Final Test Loss: {test_loss:.4f}")
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
# Final model training started.
# Epoch 1/200, Loss: 1.4361
# Epoch 11/200, Loss: 1.3412
# Epoch 21/200, Loss: 1.3425
# Epoch 31/200, Loss: 0.3450
# Epoch 41/200, Loss: 0.2953
# Epoch 51/200, Loss: 0.2802
# Epoch 61/200, Loss: 0.2653
# Epoch 71/200, Loss: 0.2581
# Epoch 81/200, Loss: 0.2490
# Epoch 91/200, Loss: 0.2475
# Epoch 101/200, Loss: 0.2411
# Epoch 111/200, Loss: 0.2402
# Epoch 121/200, Loss: 0.2332
# Epoch 131/200, Loss: 0.2294
# Epoch 141/200, Loss: 0.2204
# Epoch 151/200, Loss: 0.2196
# Epoch 161/200, Loss: 0.2163
# Epoch 171/200, Loss: 0.2116
# Epoch 181/200, Loss: 0.2128
# Epoch 191/200, Loss: 0.2054
# Epoch 200/200, Loss: 0.2053
# Final model training completed.
# Final Test Loss: 0.2672

# %%
# Scatter plot: Predictions vs Ground Truth
y_test_pred = y_test_pred.flatten()
y_test_true = y_test.flatten()

plt.figure(figsize=(8, 8))
plt.scatter(y_test_pred, y_test_true, alpha=0.6, edgecolors='k', label="Predictions")
plt.plot([y_test_true.min(), y_test_true.max()], [y_test_true.min(), y_test_true.max()], color='red', linestyle='--', label="Ideal")
plt.xlabel("Model Predictions")
plt.ylabel("Ground Truth")
plt.title("Predictions vs Ground Truth (Test Set)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Task f)

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    confusion_matrix,
    ConfusionMatrixDisplay
)

set_seed(seed)
generator = torch.Generator()
generator.manual_seed(seed)


# Step 1: Load and Preprocess the Dataset
X, y = fetch_california_housing(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=302)

# Sanity check: Dataset shapes
print(f"Initial shapes - X_train: {X_train.shape}, y_train: {y_train.shape}, X_test: {X_test.shape}, y_test: {y_test.shape}")

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Sanity check: Feature scaling
print(f"After scaling - X_train mean: {X_train.mean():.2f}, std: {X_train.std():.2f}")
print(f"After scaling - X_test mean: {X_test.mean():.2f}, std: {X_test.std():.2f}")

# Transform target into binary labels
y_train = (y_train >= 2).astype(int)  # 2 corresponds to $200,000
y_test = (y_test >= 2).astype(int)

# Sanity check: Unique values in target variables
print(f"Unique values in y_train: {set(y_train)}, Unique values in y_test: {set(y_test)}")

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# Print dimensions for verification
print(f"Final shapes - X_train: {X_train.shape}, y_train: {y_train.shape}, X_test: {X_test.shape}, y_test: {y_test.shape}")

# Step 2: Define the Model Architecture
class BinaryClassifier(nn.Module):
    def __init__(self, architecture):
        super(BinaryClassifier, self).__init__()
        layers = []
        for i in range(len(architecture) - 1):
            layers.append(nn.Linear(architecture[i], architecture[i + 1]))
            if i < len(architecture) - 2:
                layers.append(nn.ReLU())
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

architecture = [8, 64, 32, 16, 1]  # Same as regression, with 1 output for binary classification
model = BinaryClassifier(architecture)
print("Model architecture:")
print(model)

# Step 3: Define Loss, Optimizer, DataLoader, and Scheduler
criterion = nn.BCEWithLogitsLoss()
optimizer_config = {"name": "SGD_Momentum", "optimizer": SGD, "params": {"lr": 1e-2, "momentum": 0.9}}
optimizer = optimizer_config["optimizer"](model.parameters(), **optimizer_config["params"])

scheduler = None
batch_size = 50

train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataset = TensorDataset(X_test, y_test)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Step 4: Train the Model with Early Stopping
num_epochs = 200
train_losses = []
val_losses = []
best_val_loss = float('inf')
patience = 8
counter = 0
best_model_path = 'best_model.pth'

for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        epoch_train_loss += loss.item()
    epoch_train_loss /= len(train_loader)
    train_losses.append(epoch_train_loss)

    model.eval()
    epoch_val_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            y_pred = model(X_batch)
            loss = criterion(y_pred, y_batch)
            epoch_val_loss += loss.item()
    epoch_val_loss /= len(val_loader)
    val_losses.append(epoch_val_loss)

    #scheduler.step(epoch_val_loss)

    if epoch % 5 == 0 or epoch == num_epochs - 1:
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}")

    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print(f"Early stopping at epoch {epoch + 1}")
            break

# Load the best model
model.load_state_dict(torch.load(best_model_path))
# Step 5: Evaluate the Model
model.eval()
y_test_pred = []
y_test_true = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        y_pred = torch.sigmoid(model(X_batch))
        y_test_pred.extend(y_pred.squeeze().tolist())
        y_test_true.extend(y_batch.squeeze().tolist())

# Convert predictions to binary labels
y_test_pred = np.array(y_test_pred)
y_test_true = np.array(y_test_true)
y_test_pred_labels = (y_test_pred >= 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test_true, y_test_pred_labels)
precision = precision_score(y_test_true, y_test_pred_labels, zero_division=0)
recall = recall_score(y_test_true, y_test_pred_labels, zero_division=0)
f1 = f1_score(y_test_true, y_test_pred_labels, zero_division=0)
roc_auc = roc_auc_score(y_test_true, y_test_pred)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

# Generate and plot confusion matrix
cm = confusion_matrix(y_test_true, y_test_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Below $200k', 'Above $200k'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# Step 6: Plot Training and Validation Loss
plt.figure()
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid()
plt.show()

# Plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test_true, y_test_pred)
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid()
plt.show()
# Out:
# Numpy random seed set to: 42
# Torch random seed set to: 42
# Initial shapes - X_train: (15480, 8), y_train: (15480,), X_test: (5160, 8), y_test: (5160,)
# After scaling - X_train mean: -0.00, std: 1.00
# After scaling - X_test mean: 0.00, std: 1.01
# Unique values in y_train: {np.int64(0), np.int64(1)}, Unique values in y_test: {np.int64(0), np.int64(1)}
# Final shapes - X_train: torch.Size([15480, 8]), y_train: torch.Size([15480, 1]), X_test: torch.Size([5160, 8]), y_test: torch.Size([5160, 1])
# Model architecture:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=8, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )
# Epoch 1/200, Train Loss: 0.5223, Val Loss: 0.3983
# Epoch 6/200, Train Loss: 0.3262, Val Loss: 0.3204
# Epoch 11/200, Train Loss: 0.3095, Val Loss: 0.3043
# Epoch 16/200, Train Loss: 0.3038, Val Loss: 0.3010
# Epoch 21/200, Train Loss: 0.2928, Val Loss: 0.2923
# Epoch 26/200, Train Loss: 0.2873, Val Loss: 0.2889
# Epoch 31/200, Train Loss: 0.2821, Val Loss: 0.2897
# Epoch 36/200, Train Loss: 0.2821, Val Loss: 0.2859
# Epoch 41/200, Train Loss: 0.2768, Val Loss: 0.2895
# Epoch 46/200, Train Loss: 0.2734, Val Loss: 0.2798
# Epoch 51/200, Train Loss: 0.2712, Val Loss: 0.2967
# Epoch 56/200, Train Loss: 0.2667, Val Loss: 0.2878
# Epoch 61/200, Train Loss: 0.2660, Val Loss: 0.2834
# Epoch 66/200, Train Loss: 0.2615, Val Loss: 0.2836
# Early stopping at epoch 67
# Accuracy: 0.8733
# Precision: 0.8696
# Recall: 0.8279
# F1 Score: 0.8483
# ROC AUC: 0.9521
# C:\Users\Naida\AppData\Local\Temp\ipykernel_17072\2063380459.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
